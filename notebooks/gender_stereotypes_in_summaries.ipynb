# %% [markdown]
# # 2. Do plot summaries contain any gender stereotypes, and if so, in what manner?

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import json
import os
import numpy as np

# %% [markdown]
# ## Movie Metadata
# Metadata for 81,741 movies, extracted from the Noverber 4, 2012 dump of Freebase.  Tab-separated; columns:
#
# 1. Wikipedia movie ID
# 2. Freebase movie ID
# 3. Movie name
# 4. Movie release date
# 5. Movie box office revenue
# 6. Movie runtime
# 7. Movie languages (Freebase ID:name tuples)
# 8. Movie countries (Freebase ID:name tuples)
# 9. Movie genres (Freebase ID:name tuples)

# %%
header = ['wikipedia_movie_id',
          'freebase_movie_id',
          'movie_name',
          'movie_release_date',
          'movie_box_office_revenue',
          'movie_runtime',
          'movie_languages',
          'movie_countries',
          'movie_genres']
movie_df = pd.read_csv('../dataset/movie.metadata.tsv', sep='\t', names=header)
# index by wikipedia_movie_id
movie_df.set_index('wikipedia_movie_id', inplace=True)
display(movie_df.head())
movie_df.info()
# Out:
#                    freebase_movie_id  \
# wikipedia_movie_id
# 975900                     /m/03vyhn
# 3196793                    /m/08yl5d
# 28463795                  /m/0crgdbh
# 9363483                   /m/0285_cd
# 261236                     /m/01mrr1
#
#                                                            movie_name  \
# wikipedia_movie_id
# 975900                                                 Ghosts of Mars
# 3196793             Getting Away with Murder: The JonBenét Ramsey ...
# 28463795                                                  Brun bitter
# 9363483                                              White Of The Eye
# 261236                                              A Woman in Flames
#
#                    movie_release_date  movie_box_office_revenue  \
# wikipedia_movie_id
# 975900                     2001-08-24                14010832.0
# 3196793                    2000-02-16                       NaN
# 28463795                         1988                       NaN
# 9363483                          1987                       NaN
# 261236                           1983                       NaN
#
#                     movie_runtime                     movie_languages  \
# wikipedia_movie_id
# 975900                       98.0  {"/m/02h40lc": "English Language"}
# 3196793                      95.0  {"/m/02h40lc": "English Language"}
# 28463795                     83.0  {"/m/05f_3": "Norwegian Language"}
# 9363483                     110.0  {"/m/02h40lc": "English Language"}
# 261236                      106.0   {"/m/04306rv": "German Language"}
#
#                                               movie_countries  \
# wikipedia_movie_id
# 975900              {"/m/09c7w0": "United States of America"}
# 3196793             {"/m/09c7w0": "United States of America"}
# 28463795                               {"/m/05b4w": "Norway"}
# 9363483                        {"/m/07ssc": "United Kingdom"}
# 261236                                {"/m/0345h": "Germany"}
#
#                                                          movie_genres
# wikipedia_movie_id
# 975900              {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 3196793             {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 28463795            {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 9363483             {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 261236                                        {"/m/07s9rl0": "Drama"}
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81741 entries, 975900 to 12476867
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   freebase_movie_id         81741 non-null  object
#  1   movie_name                81741 non-null  object
#  2   movie_release_date        74839 non-null  object
#  3   movie_box_office_revenue  8401 non-null   float64
#  4   movie_runtime             61291 non-null  float64
#  5   movie_languages           81741 non-null  object
#  6   movie_countries           81741 non-null  object
#  7   movie_genres              81741 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 5.6+ MB

# %% [markdown]
# ## Character Metadata
# Metadata for 450,669 characters aligned to the movies above, extracted from the Noverber 4, 2012 dump of Freebase.  Tab-separated; columns:
#
# 1. Wikipedia movie ID
# 2. Freebase movie ID
# 3. Movie release date
# 4. Character name
# 5. Actor date of birth
# 6. Actor gender
# 7. Actor height (in meters)
# 8. Actor ethnicity (Freebase ID)
# 9. Actor name
# 10. Actor age at movie release
# 11. Freebase character/actor map ID
# 12. Freebase character ID
# 13. Freebase actor ID

# %%
header = ['wikipedia_movie_id', 'freebase_movie_id', 'movie_release_date', 'character_name', 'actor_date_of_birth',
          'actor_gender', 'actor_height', 'actor_ethnicity', 'actor_name', 'actor_age_at_release',
          'freebase_character_actor_map_id', 'freebase_character_id', 'freebase_actor_id']
character_df = pd.read_csv('../dataset/character.metadata.tsv', sep='\t', names=header)
character_df.head()
# Out:
#    wikipedia_movie_id freebase_movie_id movie_release_date  \
# 0              975900         /m/03vyhn         2001-08-24
# 1              975900         /m/03vyhn         2001-08-24
# 2              975900         /m/03vyhn         2001-08-24
# 3              975900         /m/03vyhn         2001-08-24
# 4              975900         /m/03vyhn         2001-08-24
#
#                character_name actor_date_of_birth actor_gender  actor_height  \
# 0                    Akooshay          1958-08-26            F         1.620
# 1  Lieutenant Melanie Ballard          1974-08-15            F         1.780
# 2         Desolation Williams          1969-06-15            M         1.727
# 3          Sgt Jericho Butler          1967-09-12            M         1.750
# 4             Bashira Kincaid          1977-09-25            F         1.650
#
#   actor_ethnicity          actor_name  actor_age_at_release  \
# 0             NaN      Wanda De Jesus                  42.0
# 1      /m/044038p  Natasha Henstridge                  27.0
# 2         /m/0x67            Ice Cube                  32.0
# 3             NaN       Jason Statham                  33.0
# 4             NaN         Clea DuVall                  23.0
#
#   freebase_character_actor_map_id freebase_character_id freebase_actor_id
# 0                      /m/0bgchxw            /m/0bgcj3x        /m/03wcfv7
# 1                       /m/0jys3m            /m/0bgchn4         /m/0346l4
# 2                       /m/0jys3g            /m/0bgchn_        /m/01vw26l
# 3                      /m/02vchl6            /m/0bgchnq         /m/034hyc
# 4                      /m/02vbb3r            /m/0bgchp9         /m/01y9xg

# %% [markdown]
# ## 2.1 Extracted Character Data from NLP

# %%
# movies = {
#     'id': {
#         'characters': {
#             'name': {
#                 {
#                     'occurrences': int,
#                     'actions_taken': list,
#                     'actions_received': list,
#                     'possessions': list,
#                     'descriptions': list
#                 }
#             }
#         }
#     }
# }

# %%
directory = '../dataset/characters/'
movies = {}
is_in_data = 0
files = os.listdir(directory)
for file in tqdm(files):
    #extract movie id (file name)
    movie_id = file.split('.')[0]

    if int(movie_id) in movie_df.index:
        is_in_data += 1

    with open(directory + file) as f:
        data = json.load(f)
        movies[movie_id] = data
print('processed movies found in movie metadata: ', is_in_data)
# Out:
# 100%|██████████| 42306/42306 [00:07<00:00, 6015.55it/s]
# processed movies found in movie metadata:  42207

# %%
# create a dataframe from the movies dictionary
movie_ids = []
character_names = []
character_occurrences = []
character_actions_taken = []
character_actions_received = []
character_possessions = []
character_descriptions = []
for movie_id, movie in tqdm(movies.items()):
    normalized_occurrences = []
    for character_name, character in movie.items():
        movie_ids.append(movie_id)
        character_names.append(character_name)
        normalized_occurrences.append(character['occurrences'])
        character_actions_taken.append(character['actions_taken'])
        character_actions_received.append(character['actions_received'])
        character_possessions.append(character['possessions'])
        character_descriptions.append(character['descriptions'])
    #append all
    character_occurrences.extend((np.array(normalized_occurrences) / sum(normalized_occurrences)).tolist())
# Out:
# 100%|██████████| 42306/42306 [00:00<00:00, 214404.83it/s]

# %%
character_nlp_data = {
    'wikipedia_movie_id': movie_ids,
    'character_name': character_names,
    'character_occurrences': character_occurrences,
    'character_actions_taken': character_actions_taken,
    'character_actions_received': character_actions_received,
    'character_possessions': character_possessions,
    'character_descriptions': character_descriptions
}
nlp_df = pd.DataFrame(character_nlp_data)
# wikipedia_movie_id to int64
nlp_df['wikipedia_movie_id'] = nlp_df['wikipedia_movie_id'].astype('int64')
# set index to wikipedia_movie_id
nlp_df.set_index('wikipedia_movie_id', inplace=True)
nlp_df.head()
nlp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 285319 entries, 34195696 to 3675194
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   character_name              285319 non-null  object
#  1   character_occurrences       285319 non-null  float64
#  2   character_actions_taken     285319 non-null  object
#  3   character_actions_received  285319 non-null  object
#  4   character_possessions       285319 non-null  object
#  5   character_descriptions      285319 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 15.2+ MB

# %%
# join nlp dataframe with movie and character dataframe on wikipedia_movie_id
df_joined = nlp_df.join(movie_df, 'wikipedia_movie_id', how='left', lsuffix='_nlp')
df_joined = character_df.join(df_joined, on=['wikipedia_movie_id'], how='left', lsuffix='_nlp', rsuffix='')

df_joined.info()
df_joined.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2747487 entries, 0 to 450668
# Data columns (total 27 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   wikipedia_movie_id               int64
#  1   freebase_movie_id_nlp            object
#  2   movie_release_date_nlp           object
#  3   character_name_nlp               object
#  4   actor_date_of_birth              object
#  5   actor_gender                     object
#  6   actor_height                     float64
#  7   actor_ethnicity                  object
#  8   actor_name                       object
#  9   actor_age_at_release             float64
#  10  freebase_character_actor_map_id  object
#  11  freebase_character_id            object
#  12  freebase_actor_id                object
#  13  character_name                   object
#  14  character_occurrences            float64
#  15  character_actions_taken          object
#  16  character_actions_received       object
#  17  character_possessions            object
#  18  character_descriptions           object
#  19  freebase_movie_id                object
#  20  movie_name                       object
#  21  movie_release_date               object
#  22  movie_box_office_revenue         float64
#  23  movie_runtime                    float64
#  24  movie_languages                  object
#  25  movie_countries                  object
#  26  movie_genres                     object
# dtypes: float64(5), int64(1), object(21)
# memory usage: 586.9+ MB
#    wikipedia_movie_id freebase_movie_id_nlp movie_release_date_nlp  \
# 0              975900             /m/03vyhn             2001-08-24
# 0              975900             /m/03vyhn             2001-08-24
# 0              975900             /m/03vyhn             2001-08-24
# 0              975900             /m/03vyhn             2001-08-24
# 0              975900             /m/03vyhn             2001-08-24
#
#   character_name_nlp actor_date_of_birth actor_gender  actor_height  \
# 0           Akooshay          1958-08-26            F          1.62
# 0           Akooshay          1958-08-26            F          1.62
# 0           Akooshay          1958-08-26            F          1.62
# 0           Akooshay          1958-08-26            F          1.62
# 0           Akooshay          1958-08-26            F          1.62
#
#   actor_ethnicity      actor_name  actor_age_at_release  ...  \
# 0             NaN  Wanda De Jesus                  42.0  ...
# 0             NaN  Wanda De Jesus                  42.0  ...
# 0             NaN  Wanda De Jesus                  42.0  ...
# 0             NaN  Wanda De Jesus                  42.0  ...
# 0             NaN  Wanda De Jesus                  42.0  ...
#
#                 character_possessions character_descriptions  \
# 0                                  []                     []
# 0                              [crew]               [police]
# 0                                  []           [Desolation]
# 0                                  []                     []
# 0  [intention, cot, report, superior]                     []
#
#   freebase_movie_id      movie_name  movie_release_date  \
# 0         /m/03vyhn  Ghosts of Mars          2001-08-24
# 0         /m/03vyhn  Ghosts of Mars          2001-08-24
# 0         /m/03vyhn  Ghosts of Mars          2001-08-24
# 0         /m/03vyhn  Ghosts of Mars          2001-08-24
# 0         /m/03vyhn  Ghosts of Mars          2001-08-24
#
#   movie_box_office_revenue movie_runtime                     movie_languages  \
# 0               14010832.0          98.0  {"/m/02h40lc": "English Language"}
# 0               14010832.0          98.0  {"/m/02h40lc": "English Language"}
# 0               14010832.0          98.0  {"/m/02h40lc": "English Language"}
# 0               14010832.0          98.0  {"/m/02h40lc": "English Language"}
# 0               14010832.0          98.0  {"/m/02h40lc": "English Language"}
#
#                              movie_countries  \
# 0  {"/m/09c7w0": "United States of America"}
# 0  {"/m/09c7w0": "United States of America"}
# 0  {"/m/09c7w0": "United States of America"}
# 0  {"/m/09c7w0": "United States of America"}
# 0  {"/m/09c7w0": "United States of America"}
#
#                                         movie_genres
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
#
# [5 rows x 27 columns]

# %%
# drop nan values
df_joined.dropna(subset=['character_name', 'character_name_nlp'], inplace=True)
df_joined.info()
df_joined.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1369971 entries, 0 to 450665
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   wikipedia_movie_id               1369971 non-null  int64
#  1   freebase_movie_id_nlp            1369971 non-null  object
#  2   movie_release_date_nlp           1362483 non-null  object
#  3   character_name_nlp               1369971 non-null  object
#  4   actor_date_of_birth              1145821 non-null  object
#  5   actor_gender                     1321890 non-null  object
#  6   actor_height                     763067 non-null   float64
#  7   actor_ethnicity                  531687 non-null   object
#  8   actor_name                       1367186 non-null  object
#  9   actor_age_at_release             1079305 non-null  float64
#  10  freebase_character_actor_map_id  1369971 non-null  object
#  11  freebase_character_id            1369971 non-null  object
#  12  freebase_actor_id                1367195 non-null  object
#  13  character_name                   1369971 non-null  object
#  14  character_occurrences            1369971 non-null  float64
#  15  character_actions_taken          1369971 non-null  object
#  16  character_actions_received       1369971 non-null  object
#  17  character_possessions            1369971 non-null  object
#  18  character_descriptions           1369971 non-null  object
#  19  freebase_movie_id                1369971 non-null  object
#  20  movie_name                       1369971 non-null  object
#  21  movie_release_date               1362483 non-null  object
#  22  movie_box_office_revenue         772637 non-null   float64
#  23  movie_runtime                    1315087 non-null  float64
#  24  movie_languages                  1369971 non-null  object
#  25  movie_countries                  1369971 non-null  object
#  26  movie_genres                     1369971 non-null  object
# dtypes: float64(5), int64(1), object(21)
# memory usage: 292.7+ MB
#    wikipedia_movie_id freebase_movie_id_nlp movie_release_date_nlp  \
# 0              975900             /m/03vyhn             2001-08-24
# 0              975900             /m/03vyhn             2001-08-24
# 0              975900             /m/03vyhn             2001-08-24
# 0              975900             /m/03vyhn             2001-08-24
# 0              975900             /m/03vyhn             2001-08-24
#
#   character_name_nlp actor_date_of_birth actor_gender  actor_height  \
# 0           Akooshay          1958-08-26            F          1.62
# 0           Akooshay          1958-08-26            F          1.62
# 0           Akooshay          1958-08-26            F          1.62
# 0           Akooshay          1958-08-26            F          1.62
# 0           Akooshay          1958-08-26            F          1.62
#
#   actor_ethnicity      actor_name  actor_age_at_release  ...  \
# 0             NaN  Wanda De Jesus                  42.0  ...
# 0             NaN  Wanda De Jesus                  42.0  ...
# 0             NaN  Wanda De Jesus                  42.0  ...
# 0             NaN  Wanda De Jesus                  42.0  ...
# 0             NaN  Wanda De Jesus                  42.0  ...
#
#                 character_possessions character_descriptions  \
# 0                                  []                     []
# 0                              [crew]               [police]
# 0                                  []           [Desolation]
# 0                                  []                     []
# 0  [intention, cot, report, superior]                     []
#
#   freebase_movie_id      movie_name  movie_release_date  \
# 0         /m/03vyhn  Ghosts of Mars          2001-08-24
# 0         /m/03vyhn  Ghosts of Mars          2001-08-24
# 0         /m/03vyhn  Ghosts of Mars          2001-08-24
# 0         /m/03vyhn  Ghosts of Mars          2001-08-24
# 0         /m/03vyhn  Ghosts of Mars          2001-08-24
#
#   movie_box_office_revenue movie_runtime                     movie_languages  \
# 0               14010832.0          98.0  {"/m/02h40lc": "English Language"}
# 0               14010832.0          98.0  {"/m/02h40lc": "English Language"}
# 0               14010832.0          98.0  {"/m/02h40lc": "English Language"}
# 0               14010832.0          98.0  {"/m/02h40lc": "English Language"}
# 0               14010832.0          98.0  {"/m/02h40lc": "English Language"}
#
#                              movie_countries  \
# 0  {"/m/09c7w0": "United States of America"}
# 0  {"/m/09c7w0": "United States of America"}
# 0  {"/m/09c7w0": "United States of America"}
# 0  {"/m/09c7w0": "United States of America"}
# 0  {"/m/09c7w0": "United States of America"}
#
#                                         movie_genres
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
#
# [5 rows x 27 columns]

# %%
# drop rows where character_name_nlp is not contained in character_name
# Drop rows where character_name_nlp is not contained in character_name
df_joined = df_joined[df_joined.apply(lambda row: row['character_name_nlp'] in row['character_name'], axis=1)]

# Print characters where character_name is longer than character_name_nlp
df_filtered = df_joined[
    df_joined.apply(lambda row: len(row['character_name']) > len(row['character_name_nlp']), axis=1)]

# print characters where character_name is longer than character_name_nlp
df_joined.info()
df_joined
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19131 entries, 45 to 450665
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   wikipedia_movie_id               19131 non-null  int64
#  1   freebase_movie_id_nlp            19131 non-null  object
#  2   movie_release_date_nlp           18945 non-null  object
#  3   character_name_nlp               19131 non-null  object
#  4   actor_date_of_birth              16826 non-null  object
#  5   actor_gender                     18666 non-null  object
#  6   actor_height                     11755 non-null  float64
#  7   actor_ethnicity                  9096 non-null   object
#  8   actor_name                       19087 non-null  object
#  9   actor_age_at_release             15983 non-null  float64
#  10  freebase_character_actor_map_id  19131 non-null  object
#  11  freebase_character_id            19131 non-null  object
#  12  freebase_actor_id                19087 non-null  object
#  13  character_name                   19131 non-null  object
#  14  character_occurrences            19131 non-null  float64
#  15  character_actions_taken          19131 non-null  object
#  16  character_actions_received       19131 non-null  object
#  17  character_possessions            19131 non-null  object
#  18  character_descriptions           19131 non-null  object
#  19  freebase_movie_id                19131 non-null  object
#  20  movie_name                       19131 non-null  object
#  21  movie_release_date               18945 non-null  object
#  22  movie_box_office_revenue         8199 non-null   float64
#  23  movie_runtime                    17419 non-null  float64
#  24  movie_languages                  19131 non-null  object
#  25  movie_countries                  19131 non-null  object
#  26  movie_genres                     19131 non-null  object
# dtypes: float64(5), int64(1), object(21)
# memory usage: 4.1+ MB
#         wikipedia_movie_id freebase_movie_id_nlp movie_release_date_nlp  \
# 45                 2238856             /m/06yc6v                2005-01
# 46                 2238856             /m/06yc6v                2005-01
# 47                 2238856             /m/06yc6v                2005-01
# 50                 2238856             /m/06yc6v                2005-01
# 100                 156558             /m/014k4y             2001-06-27
# ...                    ...                   ...                    ...
# 450556             6456053             /m/0g605h             1964-12-31
# 450585            24997872            /m/09g6klx             2010-05-07
# 450613            22545667            /m/05zrrsp                   1932
# 450652              913762             /m/03pcrp             1992-05-21
# 450665              913762             /m/03pcrp             1992-05-21
#
#        character_name_nlp actor_date_of_birth actor_gender  actor_height  \
# 45                 Andrew          1966-04-10            M          1.93
# 46                Heather          1988-08-19            F           NaN
# 47                Rebecca          1989-12-05            F          1.68
# 50                    Pam                 NaN            M           NaN
# 100                Yvette          1970-09-11            F          1.65
# ...                   ...                 ...          ...           ...
# 450556               Fane          1924-12-19            M           NaN
# 450585               Raja          1951-09-07            M          1.78
# 450613             Laurie          1895-11-30            M           NaN
# 450652             Hibiki          1970-03-01            M           NaN
# 450665             Hibiki          1965-04-12            M           NaN
#
#        actor_ethnicity          actor_name  actor_age_at_release  ...  \
# 45                 NaN  Brad William Henke                   NaN  ...
# 46                 NaN     Natasha Slayton                   NaN  ...
# 47                 NaN    Najarra Townsend                   NaN  ...
# 50                 NaN      JoNell Kennedy                   NaN  ...
# 100            /m/0x67    Taraji P. Henson                  30.0  ...
# ...                ...                 ...                   ...  ...
# 450556             NaN       Edmund Purdom                  40.0  ...
# 450585       /m/04mvp8           Mammootty                  58.0  ...
# 450613             NaN      Richard Dolman                   NaN  ...
# 450652             NaN    Tsutomu Takayama                  22.0  ...
# 450665             NaN       Jonathan Fahn                  27.0  ...
#
#                                     character_possessions  \
# 45                                                     []
# 46                                                     []
# 47                                                     []
# 50                                                     []
# 100     [mother, daddy, dismay, son, son, son, wallet,...
# ...                                                   ...
# 450556                                                 []
# 450585                                                 []
# 450613                                                 []
# 450652                                                 []
# 450665                                                 []
#
#               character_descriptions freebase_movie_id  \
# 45                                []         /m/06yc6v
# 46                                []         /m/06yc6v
# 47                                []         /m/06yc6v
# 50                                []         /m/06yc6v
# 100     [girlfriend, slapping, rape]         /m/014k4y
# ...                              ...               ...
# 450556                            []         /m/0g605h
# 450585                     [Madurai]        /m/09g6klx
# 450613                            []        /m/05zrrsp
# 450652                            []         /m/03pcrp
# 450665                            []         /m/03pcrp
#
#                                                movie_name  movie_release_date  \
# 45                        Me and You and Everyone We Know             2005-01
# 46                        Me and You and Everyone We Know             2005-01
# 47                        Me and You and Everyone We Know             2005-01
# 50                        Me and You and Everyone We Know             2005-01
# 100                                              Baby Boy          2001-06-27
# ...                                                   ...                 ...
# 450556                             The Yellow Rolls-Royce          1964-12-31
# 450585                                       Pokkiri Raja          2010-05-07
# 450613                         Looking on the Bright Side                1932
# 450652  The Super Dimension Fortress Macross II: Lover...          1992-05-21
# 450665  The Super Dimension Fortress Macross II: Lover...          1992-05-21
#
#        movie_box_office_revenue movie_runtime  \
# 45                    8012838.0          91.0
# 46                    8012838.0          91.0
# 47                    8012838.0          91.0
# 50                    8012838.0          91.0
# 100                  29381649.0         123.0
# ...                         ...           ...
# 450556                5400000.0         122.0
# 450585                      NaN         136.0
# 450613                      NaN          78.0
# 450652                      NaN         150.0
# 450665                      NaN         150.0
#
#                            movie_languages  \
# 45      {"/m/02h40lc": "English Language"}
# 46      {"/m/02h40lc": "English Language"}
# 47      {"/m/02h40lc": "English Language"}
# 50      {"/m/02h40lc": "English Language"}
# 100     {"/m/02h40lc": "English Language"}
# ...                                    ...
# 450556  {"/m/02h40lc": "English Language"}
# 450585  {"/m/0999q": "Malayalam Language"}
# 450613  {"/m/02h40lc": "English Language"}
# 450652   {"/m/03_9r": "Japanese Language"}
# 450665   {"/m/03_9r": "Japanese Language"}
#
#                                           movie_countries  \
# 45      {"/m/09c7w0": "United States of America", "/m/...
# 46      {"/m/09c7w0": "United States of America", "/m/...
# 47      {"/m/09c7w0": "United States of America", "/m/...
# 50      {"/m/09c7w0": "United States of America", "/m/...
# 100             {"/m/09c7w0": "United States of America"}
# ...                                                   ...
# 450556                     {"/m/07ssc": "United Kingdom"}
# 450585                              {"/m/03rk0": "India"}
# 450613                     {"/m/07ssc": "United Kingdom"}
# 450652                              {"/m/03_3d": "Japan"}
# 450665                              {"/m/03_3d": "Japan"}
#
#                                              movie_genres
# 45      {"/m/06cvj": "Romantic comedy", "/m/0219x_": "...
# 46      {"/m/06cvj": "Romantic comedy", "/m/0219x_": "...
# 47      {"/m/06cvj": "Romantic comedy", "/m/0219x_": "...
# 50      {"/m/06cvj": "Romantic comedy", "/m/0219x_": "...
# 100     {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# ...                                                   ...
# 450556  {"/m/07s9rl0": "Drama", "/m/03p5xs": "Comedy o...
# 450585                            {"/m/07s9rl0": "Drama"}
# 450613  {"/m/04t36": "Musical", "/m/05p553": "Comedy f...
# 450652  {"/m/06n90": "Science Fiction", "/m/0gw5n2f": ...
# 450665  {"/m/06n90": "Science Fiction", "/m/0gw5n2f": ...
#
# [19131 rows x 27 columns]

# %% [markdown]
# ## Character Complexity
#
# lets look at the complexity of characters through the years for female characters in US action movies

# %%
df_joined_sub = df_joined[
    (df_joined['movie_countries'].str.contains('United States')) & (df_joined['movie_genres'].str.contains('Action'))]
df_joined_sub
# Out:
#         wikipedia_movie_id freebase_movie_id_nlp movie_release_date_nlp  \
# 397               27556929            /m/04j0jtp                   1996
# 903                 362719             /m/01_mdl             1978-12-10
# 917                 362719             /m/01_mdl             1978-12-10
# 1067              24416479            /m/07s7_c0             1991-08-31
# 2248               5884079             /m/0fbrd7             2008-08-22
# ...                    ...                   ...                    ...
# 450214               43452              /m/0bx0l             1962-12-10
# 450215               43452              /m/0bx0l             1962-12-10
# 450298              181601             /m/018tmf             1997-09-06
# 450350             2472440             /m/07gf00             1997-01-10
# 450356             2472440             /m/07gf00             1997-01-10
#
#        character_name_nlp actor_date_of_birth actor_gender  actor_height  \
# 397               Vlachos          1946-05-02            M         1.700
# 903                  Otis          1937-07-06            M         1.727
# 917                Jor-El          1924-04-03            M         1.750
# 1067              Lyranna          1952-12-12            F         1.778
# 2248                  Joe          1964-01-07            M         1.830
# ...                   ...                 ...          ...           ...
# 450214             Farraj          1944-07-21            M           NaN
# 450215               Daud                 NaN          NaN           NaN
# 450298            Stephen          1963-08-07            M         1.790
# 450350             Stubbs          1955-03-29            M         1.850
# 450356             Maggie          1951-08-06            F         1.600
#
#        actor_ethnicity            actor_name  actor_age_at_release  ...  \
# 397          /m/02w7gg          David Suchet                  49.0  ...
# 903                NaN            Ned Beatty                  41.0  ...
# 917          /m/07mqps         Marlon Brando                  54.0  ...
# 1067               NaN         Sarah Douglas                  38.0  ...
# 2248         /m/01qhm_          Nicolas Cage                  44.0  ...
# ...                ...                   ...                   ...  ...
# 450214             NaN            Michel Ray                  18.0  ...
# 450215             NaN           John Dimech                   NaN  ...
# 450298         /m/0x67  Harold Perrineau Jr.                  34.0  ...
# 450350       /m/03bkbh       Brendan Gleeson                  41.0  ...
# 450356             NaN       Catherine Hicks                  45.0  ...
#
#                                     character_possessions  \
# 397                                                    []
# 903                                                    []
# 917                      [eminence, belief, son, warning]
# 1067                                                   []
# 2248    [go-between, execution, target, target, house,...
# ...                                                   ...
# 450214                                                 []
# 450215                                          [servant]
# 450298                                                 []
# 450350                                                 []
# 450356                                                 []
#
#            character_descriptions freebase_movie_id  \
# 397     [company, representative]        /m/04j0jtp
# 903                            []         /m/01_mdl
# 917                   [scientist]         /m/01_mdl
# 1067                           []        /m/07s7_c0
# 2248                     [Hitman]         /m/0fbrd7
# ...                           ...               ...
# 450214                         []          /m/0bx0l
# 450215                         []          /m/0bx0l
# 450298                         []         /m/018tmf
# 450350                         []         /m/07gf00
# 450356                         []         /m/07gf00
#
#                                        movie_name  movie_release_date  \
# 397                                 Deadly Voyage                1996
# 903                                      Superman          1978-12-10
# 917                                      Superman          1978-12-10
# 1067    Beastmaster 2: Through the Portal of Time          1991-08-31
# 2248                            Bangkok Dangerous          2008-08-22
# ...                                           ...                 ...
# 450214                         Lawrence of Arabia          1962-12-10
# 450215                         Lawrence of Arabia          1962-12-10
# 450298                                   The Edge          1997-09-06
# 450350                                 Turbulence          1997-01-10
# 450356                                 Turbulence          1997-01-10
#
#        movie_box_office_revenue movie_runtime  \
# 397                         NaN          90.0
# 903                 300218018.0         151.0
# 917                 300218018.0         151.0
# 1067                   869235.0         107.0
# 2248                 82486154.0          97.0
# ...                         ...           ...
# 450214                      NaN         228.0
# 450215                      NaN         228.0
# 450298               43312294.0         117.0
# 450350               11538235.0         101.0
# 450356               11538235.0         101.0
#
#                                           movie_languages  \
# 397                    {"/m/02h40lc": "English Language"}
# 903                    {"/m/02h40lc": "English Language"}
# 917                    {"/m/02h40lc": "English Language"}
# 1067                   {"/m/02h40lc": "English Language"}
# 2248    {"/m/02h40lc": "English Language", "/m/0c_v2":...
# ...                                                   ...
# 450214  {"/m/0jzc": "Arabic Language", "/m/02h40lc": "...
# 450215  {"/m/0jzc": "Arabic Language", "/m/02h40lc": "...
# 450298                 {"/m/02h40lc": "English Language"}
# 450350                 {"/m/02h40lc": "English Language"}
# 450356                 {"/m/02h40lc": "English Language"}
#
#                                           movie_countries  \
# 397     {"/m/09c7w0": "United States of America", "/m/...
# 903     {"/m/09c7w0": "United States of America", "/m/...
# 917     {"/m/09c7w0": "United States of America", "/m/...
# 1067            {"/m/09c7w0": "United States of America"}
# 2248            {"/m/09c7w0": "United States of America"}
# ...                                                   ...
# 450214  {"/m/09c7w0": "United States of America", "/m/...
# 450215  {"/m/09c7w0": "United States of America", "/m/...
# 450298          {"/m/09c7w0": "United States of America"}
# 450350          {"/m/09c7w0": "United States of America"}
# 450356          {"/m/09c7w0": "United States of America"}
#
#                                              movie_genres
# 397     {"/m/01jfsb": "Thriller", "/m/0cq22f9": "Actio...
# 903     {"/m/06n90": "Science Fiction", "/m/03k9fj": "...
# 917     {"/m/06n90": "Science Fiction", "/m/03k9fj": "...
# 1067    {"/m/0dz8b": "Sword and sorcery", "/m/06n90": ...
# 2248    {"/m/0lsxr": "Crime Fiction", "/m/01jfsb": "Th...
# ...                                                   ...
# 450214  {"/m/0hn10": "LGBT", "/m/02p0szs": "Historical...
# 450215  {"/m/0hn10": "LGBT", "/m/02p0szs": "Historical...
# 450298  {"/m/01jfsb": "Thriller", "/m/02kdv5l": "Actio...
# 450350  {"/m/01jfsb": "Thriller", "/m/01drsx": "Disast...
# 450356  {"/m/01jfsb": "Thriller", "/m/01drsx": "Disast...
#
# [2741 rows x 27 columns]

# %%
import pandas as pd


def safe_convert_to_datetime(df, column_name):
    """
    Safely converts a column to datetime, handling out-of-range and invalid dates.
    """

    # Function to safely convert individual dates
    def safe_convert(date_str):
        try:
            return pd.to_datetime(date_str)
        except (ValueError, OverflowError):
            return pd.NaT  # Return 'Not a Time' for invalid or out-of-range dates

    # Apply the safe conversion to the specified column
    df[column_name] = df[column_name].apply(safe_convert)

    # Filter out rows with invalid dates
    df = df[df[column_name].notna()]

    return df


# Apply this function to your DataFrames
women = safe_convert_to_datetime(df_joined_sub[df_joined_sub['actor_gender'] == 'F'].copy(), 'movie_release_date')
men = safe_convert_to_datetime(df_joined_sub[df_joined_sub['actor_gender'] == 'M'].copy(), 'movie_release_date')

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# change movie release date to date

women = women.copy()

plt.figure(figsize=(10, 6))  # Adjust figure size as needed
plt.scatter(women['movie_release_date'], women['character_occurrences'])
plt.xlabel('Movie Release Date')
plt.ylabel('Fraction of character mentions in a movie plot summary')
plt.title('Importance of women characters in movies')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))  # Change format if needed
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=120))  # Adjust interval as needed

plt.gcf().autofmt_xdate()  # Rotate date labels for better readability
plt.show()

# %%
# same for men
men = men.copy()

plt.figure(figsize=(10, 6))  # Adjust figure size as needed
plt.scatter(men['movie_release_date'], men['character_occurrences'])
plt.xlabel('Movie Release Date')
plt.title('Importance of men characters in movies')
plt.ylabel('Fraction of character mentions in a movie plot summary')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))  # Change format if needed
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=120))  # Adjust interval as needed

plt.gcf().autofmt_xdate()  # Rotate date labels for better readability
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


def plot_data(df, gender_label, agg_column, agg_func, window_size=1):
    yearly_agg = df.groupby('year')[agg_column].agg(agg_func).reset_index()
    if window_size > 1:
        yearly_agg[agg_column] = yearly_agg[agg_column].rolling(window=window_size, min_periods=1).mean()
    plt.plot(yearly_agg['year'], yearly_agg[agg_column], marker='o', label=gender_label)


def plot_gender_comparison(women_df, men_df, agg_column, agg_func, smoothing_window=1):
    """
    Plots a comparison between men and women dataframes for a given column and aggregation function.

    :param women_df: DataFrame for women.
    :param men_df: DataFrame for men.
    :param agg_column: The column to aggregate.
    :param agg_func: The aggregation function to use.
    :param plot_title: Title of the plot.
    :param y_axis_label: Y-axis label of the plot.
    """
    # Ensure that the date column is in datetime format
    women_df['movie_release_date'] = pd.to_datetime(women_df['movie_release_date'])
    men_df['movie_release_date'] = pd.to_datetime(men_df['movie_release_date'])

    # Extract year from movie_release_date
    women_df['year'] = women_df['movie_release_date'].dt.year
    men_df['year'] = men_df['movie_release_date'].dt.year

    # Setup the figure
    plt.figure(figsize=(10, 6))

    # Plot for Women
    plot_data(women_df, 'Women', agg_column, agg_func, smoothing_window)
    plot_data(men_df, 'Men', agg_column, agg_func, smoothing_window)

    # Formatting the plot
    plt.xlabel('Year')
    plt.ylabel(f'{agg_func} {agg_column} per year')
    plt.title(
        f'Yearly Comparison of Character Occurrences {"(moving average window=" + str(smoothing_window) + ")" if smoothing_window > 1 else ""}')
    plt.grid(True)
    plt.legend()

    # Show plot
    plt.show()


def plot_binned_gender_comparison(dfw, dfm, agg_column, agg_func, bin_size=10):
    """
    Bin the data by period of bin_size years. Plot the mean of the data in each bin.
    """
    # Ensure that the date column is in datetime format
    dfw['movie_release_date'] = pd.to_datetime(dfw['movie_release_date'])
    dfm['movie_release_date'] = pd.to_datetime(dfm['movie_release_date'])

    # Extract year from movie_release_date
    dfw['year'] = dfw['movie_release_date'].dt.year
    dfm['year'] = dfm['movie_release_date'].dt.year

    # Setup the figure
    plt.figure(figsize=(10, 6))

    # Bin the data
    dfw['year'] = dfw['year'] // bin_size * bin_size
    dfm['year'] = dfm['year'] // bin_size * bin_size

    # aggregate the data
    plot_data(dfw, 'Women', agg_column, agg_func, 1)
    plot_data(dfm, 'Men', agg_column, agg_func, 1)

    # Formatting the plot
    plt.xlabel('Year')
    plt.ylabel(f'{agg_func} {agg_column} per year')
    plt.title(f'Yearly Comparison of Character Occurrences grouped by {bin_size} years')
    plt.grid(True)
    plt.legend()


# Example usage:
plot_gender_comparison(women, men, 'character_occurrences', 'mean', 5)
plot_binned_gender_comparison(women, men, 'character_occurrences', 'mean', 5)
