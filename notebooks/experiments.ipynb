# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %config InlineBackend
# %load_ext autoreload
# %autoreload 2
# Out:
# InlineBackend(InlineBackendConfig) options
# ----------------------------------------
# InlineBackend.close_figures=<Bool>
#     Close all figures at the end of each cell.
#             When True, ensures that each cell starts with no active figures, but it
#             also means that one must keep track of references in order to edit or
#             redraw figures in subsequent cells. This mode is ideal for the notebook,
#             where residual plots from other cells might be surprising.
#             When False, one must call figure() to create new figures. This means
#             that gcf() and getfigs() can reference figures created in other cells,
#             and the active figure can continue to be edited with pylab/pyplot
#             methods that reference the current active figure. This mode facilitates
#             iterative editing of figures, and behaves most consistently with
#             other matplotlib backends, but figure barriers between cells must
#             be explicit.
#     Current: True
# InlineBackend.figure_format=<Unicode>
#     The figure format to enable (deprecated
#                                              use `figure_formats` instead)
#     Current: 'retina'
# InlineBackend.figure_formats=<set-item-1>...
#     A set of figure formats to enable: 'png',
#                     'retina', 'jpeg', 'svg', 'pdf'.
#     Current: {'retina'}
# InlineBackend.print_figure_kwargs=<key-1>=<value-1>...
#     Extra kwargs to be passed to fig.canvas.print_figure.
#             Logical examples include: bbox_inches, quality (for jpeg figures),
#     etc.
#     Current: {'bbox_inches': 'tight'}
# InlineBackend.rc=<key-1>=<value-1>...
#     Dict to manage matplotlib configuration defaults in the inline
#             backend. As of v0.1.4 IPython/Jupyter do not override defaults out of
#             the box, but third-party tools may use it to manage rc data. To change
#             personal defaults for matplotlib,  use matplotlib's configuration
#             tools, or customize this class in your `ipython_config.py` file for
#             IPython/Jupyter-specific usage.
#     Current: {}

# %%
header = ['wiki_movie_id', 'freebase_movie_id', 'movie_release_date', 'character_name', 'actor_date_of_birth',
          'actor_gender', 'actor_height', 'actor_ethnicity', 'actor_name', 'actor_age_at_release',
          'freebase_character_actor_map_id', 'freebase_character_id', 'freebase_actor_id']
df = pd.read_csv('../dataset/character.metadata.tsv', sep='\t', names=header)
df.head()
# Out:
#    wiki_movie_id freebase_movie_id movie_release_date  \
# 0         975900         /m/03vyhn         2001-08-24
# 1         975900         /m/03vyhn         2001-08-24
# 2         975900         /m/03vyhn         2001-08-24
# 3         975900         /m/03vyhn         2001-08-24
# 4         975900         /m/03vyhn         2001-08-24
#
#                character_name actor_date_of_birth actor_gender  actor_height  \
# 0                    Akooshay          1958-08-26            F         1.620
# 1  Lieutenant Melanie Ballard          1974-08-15            F         1.780
# 2         Desolation Williams          1969-06-15            M         1.727
# 3          Sgt Jericho Butler          1967-09-12            M         1.750
# 4             Bashira Kincaid          1977-09-25            F         1.650
#
#   actor_ethnicity          actor_name  actor_age_at_release  \
# 0             NaN      Wanda De Jesus                  42.0
# 1      /m/044038p  Natasha Henstridge                  27.0
# 2         /m/0x67            Ice Cube                  32.0
# 3             NaN       Jason Statham                  33.0
# 4             NaN         Clea DuVall                  23.0
#
#   freebase_character_actor_map_id freebase_character_id freebase_actor_id
# 0                      /m/0bgchxw            /m/0bgcj3x        /m/03wcfv7
# 1                       /m/0jys3m            /m/0bgchn4         /m/0346l4
# 2                       /m/0jys3g            /m/0bgchn_        /m/01vw26l
# 3                      /m/02vchl6            /m/0bgchnq         /m/034hyc
# 4                      /m/02vbb3r            /m/0bgchp9         /m/01y9xg

# %%
import xml.etree.ElementTree as ET
import gzip
import xmltodict

movie_id = '23270459'
# Load and parse the XML file
directory = '../dataset/corenlp_plot_summaries/'
file_path = directory + movie_id + '.xml.gz'

# %%
def extract_corenlp_xml(filename):
    tree = ET.parse(gzip.open(filename))
    #xml to json
    xmlstr = ET.tostring(tree.getroot(), encoding='utf8', method='xml')
    data_dict = xmltodict.parse(xmlstr)
    return data_dict

# %%
file = extract_corenlp_xml(file_path)

# %%
file
# Out:
# {'root': {'document': {'sentences': {'sentence': [{'@id': '1',
#       'tokens': {'token': [{'@id': '1',
#          'word': 'Former',
#          'lemma': 'former',
#          'CharacterOffsetBegin': '1',
#          'CharacterOffsetEnd': '7',
#          'POS': 'JJ',
#          'NER': 'O'},
#         {'@id': '2',
#          'word': 'dream',
#          'lemma': 'dream',
#          'CharacterOffsetBegin': '8',
#          'CharacterOffsetEnd': '13',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '3',
#          'word': 'architect',
#          'lemma': 'architect',
#          'CharacterOffsetBegin': '14',
#          'CharacterOffsetEnd': '23',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '4',
#          'word': 'Dominick',
#          'lemma': 'Dominick',
#          'CharacterOffsetBegin': '24',
#          'CharacterOffsetEnd': '32',
#          'POS': 'NNP',
#          'NER': 'PERSON'},
#         {'@id': '5',
#          'word': '``',
#          'lemma': '``',
#          'CharacterOffsetBegin': '33',
#          'CharacterOffsetEnd': '34',
#          'POS': '``',
#          'NER': 'O'},
#         {'@id': '6',
#          'word': 'Dom',
#          'lemma': 'Dom',
#          'CharacterOffsetBegin': '34',
#          'CharacterOffsetEnd': '37',
#          'POS': 'NNP',
#          'NER': 'O'},
#         {'@id': '7',
#          'word': "''",
#          'lemma': "''",
#          'CharacterOffsetBegin': '37',
#          'CharacterOffsetEnd': '38',
#          'POS': "''",
#          'NER': 'O'},
#         {'@id': '8',
#          'word': 'Cobb',
#          'lemma': 'Cobb',
#          'CharacterOffsetBegin': '39',
#          'CharacterOffsetEnd': '43',
#          'POS': 'NNP',
#          'NER': 'PERSON'},
#         {'@id': '9',
#          'word': 'and',
#          'lemma': 'and',
#          'CharacterOffsetBegin': '45',
#          'CharacterOffsetEnd': '48',
#          'POS': 'CC',
#          'NER': 'O'},
#         {'@id': '10',
#          'word': 'business',
#          'lemma': 'business',
#          'CharacterOffsetBegin': '49',
#          'CharacterOffsetEnd': '57',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '11',
#          'word': 'partner',
#          'lemma': 'partner',
#          'CharacterOffsetBegin': '58',
#          'CharacterOffsetEnd': '65',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '12',
#          'word': 'Arthur',
#          'lemma': 'Arthur',
#          'CharacterOffsetBegin': '66',
#          'CharacterOffsetEnd': '72',
#          'POS': 'NNP',
#          'NER': 'PERSON'},
#         {'@id': '13',
#          'word': 'perform',
#          'lemma': 'perform',
#          'CharacterOffsetBegin': '74',
#          'CharacterOffsetEnd': '81',
#          'POS': 'VB',
#          'NER': 'O'},
#         {'@id': '14',
#          'word': 'corporate',
#          'lemma': 'corporate',
#          'CharacterOffsetBegin': '82',
#          'CharacterOffsetEnd': '91',
#          'POS': 'JJ',
#          'NER': 'O'},
#         {'@id': '15',
#          'word': 'espionage',
#          'lemma': 'espionage',
#          'CharacterOffsetBegin': '92',
#          'CharacterOffsetEnd': '101',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '16',
#          'word': 'by',
#          'lemma': 'by',
#          'CharacterOffsetBegin': '102',
#          'CharacterOffsetEnd': '104',
#          'POS': 'IN',
#          'NER': 'O'},
#         {'@id': '17',
#          'word': 'using',
#          'lemma': 'use',
#          'CharacterOffsetBegin': '105',
#          'CharacterOffsetEnd': '110',
#          'POS': 'VBG',
#          'NER': 'O'},
#         {'@id': '18',
#          'word': 'an',
#          'lemma': 'a',
#          'CharacterOffsetBegin': '111',
#          'CharacterOffsetEnd': '113',
#          'POS': 'DT',
#          'NER': 'O'},
#         {'@id': '19',
#          'word': 'experimental',
#          'lemma': 'experimental',
#          'CharacterOffsetBegin': '114',
#          'CharacterOffsetEnd': '126',
#          'POS': 'JJ',
#          'NER': 'O'},
#         {'@id': '20',
#          'word': 'military-developed',
#          'lemma': 'military-developed',
#          'CharacterOffsetBegin': '127',
#          'CharacterOffsetEnd': '145',
#          'POS': 'JJ',
#          'NER': 'O'},
#         {'@id': '21',
#          'word': 'machine',
#          'lemma': 'machine',
#          'CharacterOffsetBegin': '146',
#          'CharacterOffsetEnd': '153',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '22',
#          'word': 'to',
#          'lemma': 'to',
#          'CharacterOffsetBegin': '154',
#          'CharacterOffsetEnd': '156',
#          'POS': 'TO',
#          'NER': 'O'},
#         {'@id': '23',
#          'word': 'infiltrate',
#          'lemma': 'infiltrate',
#          'CharacterOffsetBegin': '157',
#          'CharacterOffsetEnd': '167',
#          'POS': 'VB',
#          'NER': 'O'},
#         {'@id': '24',
#          'word': 'the',
#          'lemma': 'the',
#          'CharacterOffsetBegin': '168',
#          'CharacterOffsetEnd': '171',
#          'POS': 'DT',
#          'NER': 'O'},
#         {'@id': '25',
#          'word': 'subconscious',
#          'lemma': 'subconscious',
#          'CharacterOffsetBegin': '172',
#          'CharacterOffsetEnd': '184',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '26',
#          'word': 'of',
#          'lemma': 'of',
#          'CharacterOffsetBegin': '185',
#          'CharacterOffsetEnd': '187',
#          'POS': 'IN',
#          'NER': 'O'},
#         {'@id': '27',
#          'word': 'their',
#          'lemma': 'they',
#          'CharacterOffsetBegin': '188',
#          'CharacterOffsetEnd': '193',
#          'POS': 'PRP$',
#          'NER': 'O'},
#         {'@id': '28',
#          'word': 'targets',
#          'lemma': 'target',
#          'CharacterOffsetBegin': '194',
#          'CharacterOffsetEnd': '201',
#          'POS': 'NNS',
#          'NER': 'O'},
#         {'@id': '29',
#          'word': 'and',
#          'lemma': 'and',
#          'CharacterOffsetBegin': '202',
#          'CharacterOffsetEnd': '205',
#          'POS': 'CC',
#          'NER': 'O'},
#         {'@id': '30',
#          'word': 'extract',
#          'lemma': 'extract',
#          'CharacterOffsetBegin': '206',
#          'CharacterOffsetEnd': '213',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '31',
#          'word': 'information',
#          'lemma': 'information',
#          'CharacterOffsetBegin': '214',
#          'CharacterOffsetEnd': '225',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '32',
#          'word': 'while',
#          'lemma': 'while',
#          'CharacterOffsetBegin': '226',
#          'CharacterOffsetEnd': '231',
#          'POS': 'IN',
#          'NER': 'O'},
#         {'@id': '33',
#          'word': 'dreaming',
#          'lemma': 'dream',
#          'CharacterOffsetBegin': '232',
#          'CharacterOffsetEnd': '240',
#          'POS': 'VBG',
#          'NER': 'O'},
#         {'@id': '34',
#          'word': ',',
#          'lemma': ',',
#          'CharacterOffsetBegin': '240',
#          'CharacterOffsetEnd': '241',
#          'POS': ',',
#          'NER': 'O'},
#         {'@id': '35',
#          'word': 'their',
#          'lemma': 'they',
#          'CharacterOffsetBegin': '242',
#          'CharacterOffsetEnd': '247',
#          'POS': 'PRP$',
#          'NER': 'O'},
#         {'@id': '36',
#          'word': 'latest',
#          'lemma': 'latest',
#          'CharacterOffsetBegin': '248',
#          'CharacterOffsetEnd': '254',
#          'POS': 'JJS',
#          'NER': 'O'},
#         {'@id': '37',
#          'word': 'target',
#          'lemma': 'target',
#          'CharacterOffsetBegin': '255',
#          'CharacterOffsetEnd': '261',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '38',
#          'word': 'being',
#          'lemma': 'be',
#          'CharacterOffsetBegin': '262',
#          'CharacterOffsetEnd': '267',
#          'POS': 'VBG',
#          'NER': 'O'},
#         {'@id': '39',
#          'word': 'powerful',
#          'lemma': 'powerful',
#          'CharacterOffsetBegin': '268',
#          'CharacterOffsetEnd': '276',
#          'POS': 'JJ',
#          'NER': 'O'},
#         {'@id': '40',
#          'word': 'Japanese',
#          'lemma': 'japanese',
#          'CharacterOffsetBegin': '277',
#          'CharacterOffsetEnd': '285',
#          'POS': 'JJ',
#          'NER': 'MISC'},
#         {'@id': '41',
#          'word': 'businessman',
#          'lemma': 'businessman',
#          'CharacterOffsetBegin': '286',
#          'CharacterOffsetEnd': '297',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '42',
#          'word': 'Saito',
#          'lemma': 'Saito',
#          'CharacterOffsetBegin': '298',
#          'CharacterOffsetEnd': '303',
#          'POS': 'NNP',
#          'NER': 'PERSON'},
#         {'@id': '43',
#          'word': '.',
#          'lemma': '.',
#          'CharacterOffsetBegin': '304',
#          'CharacterOffsetEnd': '305',
#          'POS': '.',
#          'NER': 'O'}]},
#       'parse': "(ROOT (NP (NP (NP (JJ Former) (NN dream) (NN architect) (NNP Dominick) (`` ``) (NNP Dom) ('' '') (NNP Cobb)) (CC and) (NP (NN business) (NN partner))) (S (NP (NNP Arthur)) (VP (VB perform) (NP (JJ corporate) (NN espionage)) (PP (IN by) (S (VP (VBG using) (NP (DT an) (JJ experimental) (JJ military-developed) (NN machine)) (S (VP (TO to) (VP (VB infiltrate) (NP (NP (DT the) (NN subconscious)) (PP (IN of) (NP (NP (PRP$ their) (NNS targets)) (CC and) (NP (NN extract) (NN information))))))))))) (SBAR (IN while) (S (VP (VBG dreaming)))))) (, ,) (S (NP (PRP$ their) (JJS latest) (NN target)) (VP (VBG being) (NP (JJ powerful) (JJ Japanese) (NN businessman) (NNP Saito)))) (. .)))",
#       'basic-dependencies': {'dep': [{'@type': 'amod',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '1', '#text': 'Former'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '2', '#text': 'dream'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '3', '#text': 'architect'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '4', '#text': 'Dominick'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '6', '#text': 'Dom'}},
#         {'@type': 'cc',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '9', '#text': 'and'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '11', '#text': 'partner'},
#          'dependent': {'@idx': '10', '#text': 'business'}},
#         {'@type': 'conj',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '11', '#text': 'partner'}},
#         {'@type': 'nsubj',
#          'governor': {'@idx': '13', '#text': 'perform'},
#          'dependent': {'@idx': '12', '#text': 'Arthur'}},
#         {'@type': 'dep',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '13', '#text': 'perform'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '15', '#text': 'espionage'},
#          'dependent': {'@idx': '14', '#text': 'corporate'}},
#         {'@type': 'dobj',
#          'governor': {'@idx': '13', '#text': 'perform'},
#          'dependent': {'@idx': '15', '#text': 'espionage'}},
#         {'@type': 'prep',
#          'governor': {'@idx': '13', '#text': 'perform'},
#          'dependent': {'@idx': '16', '#text': 'by'}},
#         {'@type': 'pcomp',
#          'governor': {'@idx': '16', '#text': 'by'},
#          'dependent': {'@idx': '17', '#text': 'using'}},
#         {'@type': 'det',
#          'governor': {'@idx': '21', '#text': 'machine'},
#          'dependent': {'@idx': '18', '#text': 'an'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '21', '#text': 'machine'},
#          'dependent': {'@idx': '19', '#text': 'experimental'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '21', '#text': 'machine'},
#          'dependent': {'@idx': '20', '#text': 'military-developed'}},
#         {'@type': 'dobj',
#          'governor': {'@idx': '17', '#text': 'using'},
#          'dependent': {'@idx': '21', '#text': 'machine'}},
#         {'@type': 'aux',
#          'governor': {'@idx': '23', '#text': 'infiltrate'},
#          'dependent': {'@idx': '22', '#text': 'to'}},
#         {'@type': 'xcomp',
#          'governor': {'@idx': '17', '#text': 'using'},
#          'dependent': {'@idx': '23', '#text': 'infiltrate'}},
#         {'@type': 'det',
#          'governor': {'@idx': '25', '#text': 'subconscious'},
#          'dependent': {'@idx': '24', '#text': 'the'}},
#         {'@type': 'dobj',
#          'governor': {'@idx': '23', '#text': 'infiltrate'},
#          'dependent': {'@idx': '25', '#text': 'subconscious'}},
#         {'@type': 'prep',
#          'governor': {'@idx': '25', '#text': 'subconscious'},
#          'dependent': {'@idx': '26', '#text': 'of'}},
#         {'@type': 'poss',
#          'governor': {'@idx': '28', '#text': 'targets'},
#          'dependent': {'@idx': '27', '#text': 'their'}},
#         {'@type': 'pobj',
#          'governor': {'@idx': '26', '#text': 'of'},
#          'dependent': {'@idx': '28', '#text': 'targets'}},
#         {'@type': 'cc',
#          'governor': {'@idx': '28', '#text': 'targets'},
#          'dependent': {'@idx': '29', '#text': 'and'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '31', '#text': 'information'},
#          'dependent': {'@idx': '30', '#text': 'extract'}},
#         {'@type': 'conj',
#          'governor': {'@idx': '28', '#text': 'targets'},
#          'dependent': {'@idx': '31', '#text': 'information'}},
#         {'@type': 'mark',
#          'governor': {'@idx': '33', '#text': 'dreaming'},
#          'dependent': {'@idx': '32', '#text': 'while'}},
#         {'@type': 'advcl',
#          'governor': {'@idx': '13', '#text': 'perform'},
#          'dependent': {'@idx': '33', '#text': 'dreaming'}},
#         {'@type': 'poss',
#          'governor': {'@idx': '37', '#text': 'target'},
#          'dependent': {'@idx': '35', '#text': 'their'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '37', '#text': 'target'},
#          'dependent': {'@idx': '36', '#text': 'latest'}},
#         {'@type': 'nsubj',
#          'governor': {'@idx': '42', '#text': 'Saito'},
#          'dependent': {'@idx': '37', '#text': 'target'}},
#         {'@type': 'cop',
#          'governor': {'@idx': '42', '#text': 'Saito'},
#          'dependent': {'@idx': '38', '#text': 'being'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '42', '#text': 'Saito'},
#          'dependent': {'@idx': '39', '#text': 'powerful'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '42', '#text': 'Saito'},
#          'dependent': {'@idx': '40', '#text': 'Japanese'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '42', '#text': 'Saito'},
#          'dependent': {'@idx': '41', '#text': 'businessman'}},
#         {'@type': 'dep',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '42', '#text': 'Saito'}}]},
#       'collapsed-dependencies': {'dep': [{'@type': 'amod',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '1', '#text': 'Former'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '2', '#text': 'dream'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '3', '#text': 'architect'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '4', '#text': 'Dominick'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '6', '#text': 'Dom'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '11', '#text': 'partner'},
#          'dependent': {'@idx': '10', '#text': 'business'}},
#         {'@type': 'conj_and',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '11', '#text': 'partner'}},
#         {'@type': 'nsubj',
#          'governor': {'@idx': '13', '#text': 'perform'},
#          'dependent': {'@idx': '12', '#text': 'Arthur'}},
#         {'@type': 'dep',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '13', '#text': 'perform'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '15', '#text': 'espionage'},
#          'dependent': {'@idx': '14', '#text': 'corporate'}},
#         {'@type': 'dobj',
#          'governor': {'@idx': '13', '#text': 'perform'},
#          'dependent': {'@idx': '15', '#text': 'espionage'}},
#         {'@type': 'prepc_by',
#          'governor': {'@idx': '13', '#text': 'perform'},
#          'dependent': {'@idx': '17', '#text': 'using'}},
#         {'@type': 'det',
#          'governor': {'@idx': '21', '#text': 'machine'},
#          'dependent': {'@idx': '18', '#text': 'an'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '21', '#text': 'machine'},
#          'dependent': {'@idx': '19', '#text': 'experimental'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '21', '#text': 'machine'},
#          'dependent': {'@idx': '20', '#text': 'military-developed'}},
#         {'@type': 'dobj',
#          'governor': {'@idx': '17', '#text': 'using'},
#          'dependent': {'@idx': '21', '#text': 'machine'}},
#         {'@type': 'aux',
#          'governor': {'@idx': '23', '#text': 'infiltrate'},
#          'dependent': {'@idx': '22', '#text': 'to'}},
#         {'@type': 'xcomp',
#          'governor': {'@idx': '17', '#text': 'using'},
#          'dependent': {'@idx': '23', '#text': 'infiltrate'}},
#         {'@type': 'det',
#          'governor': {'@idx': '25', '#text': 'subconscious'},
#          'dependent': {'@idx': '24', '#text': 'the'}},
#         {'@type': 'dobj',
#          'governor': {'@idx': '23', '#text': 'infiltrate'},
#          'dependent': {'@idx': '25', '#text': 'subconscious'}},
#         {'@type': 'poss',
#          'governor': {'@idx': '28', '#text': 'targets'},
#          'dependent': {'@idx': '27', '#text': 'their'}},
#         {'@type': 'prep_of',
#          'governor': {'@idx': '25', '#text': 'subconscious'},
#          'dependent': {'@idx': '28', '#text': 'targets'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '31', '#text': 'information'},
#          'dependent': {'@idx': '30', '#text': 'extract'}},
#         {'@type': 'conj_and',
#          'governor': {'@idx': '28', '#text': 'targets'},
#          'dependent': {'@idx': '31', '#text': 'information'}},
#         {'@type': 'mark',
#          'governor': {'@idx': '33', '#text': 'dreaming'},
#          'dependent': {'@idx': '32', '#text': 'while'}},
#         {'@type': 'advcl',
#          'governor': {'@idx': '13', '#text': 'perform'},
#          'dependent': {'@idx': '33', '#text': 'dreaming'}},
#         {'@type': 'poss',
#          'governor': {'@idx': '37', '#text': 'target'},
#          'dependent': {'@idx': '35', '#text': 'their'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '37', '#text': 'target'},
#          'dependent': {'@idx': '36', '#text': 'latest'}},
#         {'@type': 'nsubj',
#          'governor': {'@idx': '42', '#text': 'Saito'},
#          'dependent': {'@idx': '37', '#text': 'target'}},
#         {'@type': 'cop',
#          'governor': {'@idx': '42', '#text': 'Saito'},
#          'dependent': {'@idx': '38', '#text': 'being'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '42', '#text': 'Saito'},
#          'dependent': {'@idx': '39', '#text': 'powerful'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '42', '#text': 'Saito'},
#          'dependent': {'@idx': '40', '#text': 'Japanese'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '42', '#text': 'Saito'},
#          'dependent': {'@idx': '41', '#text': 'businessman'}},
#         {'@type': 'dep',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '42', '#text': 'Saito'}}]},
#       'collapsed-ccprocessed-dependencies': {'dep': [{'@type': 'amod',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '1', '#text': 'Former'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '2', '#text': 'dream'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '3', '#text': 'architect'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '4', '#text': 'Dominick'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '6', '#text': 'Dom'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '11', '#text': 'partner'},
#          'dependent': {'@idx': '10', '#text': 'business'}},
#         {'@type': 'conj_and',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '11', '#text': 'partner'}},
#         {'@type': 'nsubj',
#          'governor': {'@idx': '13', '#text': 'perform'},
#          'dependent': {'@idx': '12', '#text': 'Arthur'}},
#         {'@type': 'dep',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '13', '#text': 'perform'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '15', '#text': 'espionage'},
#          'dependent': {'@idx': '14', '#text': 'corporate'}},
#         {'@type': 'dobj',
#          'governor': {'@idx': '13', '#text': 'perform'},
#          'dependent': {'@idx': '15', '#text': 'espionage'}},
#         {'@type': 'prepc_by',
#          'governor': {'@idx': '13', '#text': 'perform'},
#          'dependent': {'@idx': '17', '#text': 'using'}},
#         {'@type': 'det',
#          'governor': {'@idx': '21', '#text': 'machine'},
#          'dependent': {'@idx': '18', '#text': 'an'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '21', '#text': 'machine'},
#          'dependent': {'@idx': '19', '#text': 'experimental'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '21', '#text': 'machine'},
#          'dependent': {'@idx': '20', '#text': 'military-developed'}},
#         {'@type': 'dobj',
#          'governor': {'@idx': '17', '#text': 'using'},
#          'dependent': {'@idx': '21', '#text': 'machine'}},
#         {'@type': 'aux',
#          'governor': {'@idx': '23', '#text': 'infiltrate'},
#          'dependent': {'@idx': '22', '#text': 'to'}},
#         {'@type': 'xcomp',
#          'governor': {'@idx': '17', '#text': 'using'},
#          'dependent': {'@idx': '23', '#text': 'infiltrate'}},
#         {'@type': 'det',
#          'governor': {'@idx': '25', '#text': 'subconscious'},
#          'dependent': {'@idx': '24', '#text': 'the'}},
#         {'@type': 'dobj',
#          'governor': {'@idx': '23', '#text': 'infiltrate'},
#          'dependent': {'@idx': '25', '#text': 'subconscious'}},
#         {'@type': 'poss',
#          'governor': {'@idx': '28', '#text': 'targets'},
#          'dependent': {'@idx': '27', '#text': 'their'}},
#         {'@type': 'prep_of',
#          'governor': {'@idx': '25', '#text': 'subconscious'},
#          'dependent': {'@idx': '28', '#text': 'targets'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '31', '#text': 'information'},
#          'dependent': {'@idx': '30', '#text': 'extract'}},
#         {'@type': 'prep_of',
#          'governor': {'@idx': '25', '#text': 'subconscious'},
#          'dependent': {'@idx': '31', '#text': 'information'}},
#         {'@type': 'conj_and',
#          'governor': {'@idx': '28', '#text': 'targets'},
#          'dependent': {'@idx': '31', '#text': 'information'}},
#         {'@type': 'mark',
#          'governor': {'@idx': '33', '#text': 'dreaming'},
#          'dependent': {'@idx': '32', '#text': 'while'}},
#         {'@type': 'advcl',
#          'governor': {'@idx': '13', '#text': 'perform'},
#          'dependent': {'@idx': '33', '#text': 'dreaming'}},
#         {'@type': 'poss',
#          'governor': {'@idx': '37', '#text': 'target'},
#          'dependent': {'@idx': '35', '#text': 'their'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '37', '#text': 'target'},
#          'dependent': {'@idx': '36', '#text': 'latest'}},
#         {'@type': 'nsubj',
#          'governor': {'@idx': '42', '#text': 'Saito'},
#          'dependent': {'@idx': '37', '#text': 'target'}},
#         {'@type': 'cop',
#          'governor': {'@idx': '42', '#text': 'Saito'},
#          'dependent': {'@idx': '38', '#text': 'being'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '42', '#text': 'Saito'},
#          'dependent': {'@idx': '39', '#text': 'powerful'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '42', '#text': 'Saito'},
#          'dependent': {'@idx': '40', '#text': 'Japanese'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '42', '#text': 'Saito'},
#          'dependent': {'@idx': '41', '#text': 'businessman'}},
#         {'@type': 'dep',
#          'governor': {'@idx': '8', '#text': 'Cobb'},
#          'dependent': {'@idx': '42', '#text': 'Saito'}}]}},
#      {'@id': '2',
#       'tokens': {'token': [{'@id': '1',
#          'word': 'Tiered',
#          'lemma': 'tiered',
#          'CharacterOffsetBegin': '306',
#          'CharacterOffsetEnd': '312',
#          'POS': 'JJ',
#          'NER': 'MISC'},
#         {'@id': '2',
#          'word': 'dream',
#          'lemma': 'dream',
#          'CharacterOffsetBegin': '313',
#          'CharacterOffsetEnd': '318',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '3',
#          'word': 'within',
#          'lemma': 'within',
#          'CharacterOffsetBegin': '319',
#          'CharacterOffsetEnd': '325',
#          'POS': 'IN',
#          'NER': 'O'},
#         {'@id': '4',
#          'word': 'a',
#          'lemma': 'a',
#          'CharacterOffsetBegin': '326',
#          'CharacterOffsetEnd': '327',
#          'POS': 'DT',
#          'NER': 'O'},
#         {'@id': '5',
#          'word': 'dream',
#          'lemma': 'dream',
#          'CharacterOffsetBegin': '328',
#          'CharacterOffsetEnd': '333',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '6',
#          'word': 'strategies',
#          'lemma': 'strategy',
#          'CharacterOffsetBegin': '334',
#          'CharacterOffsetEnd': '344',
#          'POS': 'NNS',
#          'NER': 'O'},
#         {'@id': '7',
#          'word': 'are',
#          'lemma': 'be',
#          'CharacterOffsetBegin': '345',
#          'CharacterOffsetEnd': '348',
#          'POS': 'VBP',
#          'NER': 'O'},
#         {'@id': '8',
#          'word': 'used',
#          'lemma': 'use',
#          'CharacterOffsetBegin': '349',
#          'CharacterOffsetEnd': '353',
#          'POS': 'VBN',
#          'NER': 'O'},
#         {'@id': '9',
#          'word': 'and',
#          'lemma': 'and',
#          'CharacterOffsetBegin': '354',
#          'CharacterOffsetEnd': '357',
#          'POS': 'CC',
#          'NER': 'O'},
#         {'@id': '10',
#          'word': 'dreamers',
#          'lemma': 'dreamer',
#          'CharacterOffsetBegin': '358',
#          'CharacterOffsetEnd': '366',
#          'POS': 'NNS',
#          'NER': 'O'},
#         {'@id': '11',
#          'word': 'awaken',
#          'lemma': 'awaken',
#          'CharacterOffsetBegin': '367',
#          'CharacterOffsetEnd': '373',
#          'POS': 'VBP',
#          'NER': 'O'},
#         {'@id': '12',
#          'word': 'by',
#          'lemma': 'by',
#          'CharacterOffsetBegin': '374',
#          'CharacterOffsetEnd': '376',
#          'POS': 'IN',
#          'NER': 'O'},
#         {'@id': '13',
#          'word': 'a',
#          'lemma': 'a',
#          'CharacterOffsetBegin': '377',
#          'CharacterOffsetEnd': '378',
#          'POS': 'DT',
#          'NER': 'O'},
#         {'@id': '14',
#          'word': 'sudden',
#          'lemma': 'sudden',
#          'CharacterOffsetBegin': '379',
#          'CharacterOffsetEnd': '385',
#          'POS': 'JJ',
#          'NER': 'O'},
#         {'@id': '15',
#          'word': 'kick',
#          'lemma': 'kick',
#          'CharacterOffsetBegin': '386',
#          'CharacterOffsetEnd': '390',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '16',
#          'word': 'or',
#          'lemma': 'or',
#          'CharacterOffsetBegin': '391',
#          'CharacterOffsetEnd': '393',
#          'POS': 'CC',
#          'NER': 'O'},
#         {'@id': '17',
#          'word': 'by',
#          'lemma': 'by',
#          'CharacterOffsetBegin': '394',
#          'CharacterOffsetEnd': '396',
#          'POS': 'IN',
#          'NER': 'O'},
#         {'@id': '18',
#          'word': 'dying',
#          'lemma': 'die',
#          'CharacterOffsetBegin': '397',
#          'CharacterOffsetEnd': '402',
#          'POS': 'VBG',
#          'NER': 'O'},
#         {'@id': '19',
#          'word': 'in',
#          'lemma': 'in',
#          'CharacterOffsetBegin': '403',
#          'CharacterOffsetEnd': '405',
#          'POS': 'IN',
#          'NER': 'O'},
#         {'@id': '20',
#          'word': 'the',
#          'lemma': 'the',
#          'CharacterOffsetBegin': '406',
#          'CharacterOffsetEnd': '409',
#          'POS': 'DT',
#          'NER': 'O'},
#         {'@id': '21',
#          'word': 'dream',
#          'lemma': 'dream',
#          'CharacterOffsetBegin': '410',
#          'CharacterOffsetEnd': '415',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '22',
#          'word': '.',
#          'lemma': '.',
#          'CharacterOffsetBegin': '415',
#          'CharacterOffsetEnd': '416',
#          'POS': '.',
#          'NER': 'O'}]},
#       'parse': '(ROOT (S (S (NP (NP (JJ Tiered) (NN dream)) (PP (IN within) (NP (DT a) (NN dream) (NNS strategies)))) (VP (VBP are) (VP (VBN used)))) (CC and) (S (NP (NNS dreamers)) (VP (VBP awaken) (PP (PP (IN by) (NP (DT a) (JJ sudden) (NN kick))) (CC or) (PP (IN by) (S (VP (VBG dying) (PP (IN in) (NP (DT the) (NN dream))))))))) (. .)))',
#       'basic-dependencies': {'dep': [{'@type': 'amod',
#          'governor': {'@idx': '2', '#text': 'dream'},
#          'dependent': {'@idx': '1', '#text': 'Tiered'}},
#         {'@type': 'nsubjpass',
#          'governor': {'@idx': '8', '#text': 'used'},
#          'dependent': {'@idx': '2', '#text': 'dream'}},
#         {'@type': 'prep',
#          'governor': {'@idx': '2', '#text': 'dream'},
#          'dependent': {'@idx': '3', '#text': 'within'}},
#         {'@type': 'det',
#          'governor': {'@idx': '6', '#text': 'strategies'},
#          'dependent': {'@idx': '4', '#text': 'a'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '6', '#text': 'strategies'},
#          'dependent': {'@idx': '5', '#text': 'dream'}},
#         {'@type': 'pobj',
#          'governor': {'@idx': '3', '#text': 'within'},
#          'dependent': {'@idx': '6', '#text': 'strategies'}},
#         {'@type': 'auxpass',
#          'governor': {'@idx': '8', '#text': 'used'},
#          'dependent': {'@idx': '7', '#text': 'are'}},
#         {'@type': 'cc',
#          'governor': {'@idx': '8', '#text': 'used'},
#          'dependent': {'@idx': '9', '#text': 'and'}},
#         {'@type': 'nsubj',
#          'governor': {'@idx': '11', '#text': 'awaken'},
#          'dependent': {'@idx': '10', '#text': 'dreamers'}},
#         {'@type': 'conj',
#          'governor': {'@idx': '8', '#text': 'used'},
#          'dependent': {'@idx': '11', '#text': 'awaken'}},
#         {'@type': 'prep',
#          'governor': {'@idx': '11', '#text': 'awaken'},
#          'dependent': {'@idx': '12', '#text': 'by'}},
#         {'@type': 'det',
#          'governor': {'@idx': '15', '#text': 'kick'},
#          'dependent': {'@idx': '13', '#text': 'a'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '15', '#text': 'kick'},
#          'dependent': {'@idx': '14', '#text': 'sudden'}},
#         {'@type': 'pobj',
#          'governor': {'@idx': '12', '#text': 'by'},
#          'dependent': {'@idx': '15', '#text': 'kick'}},
#         {'@type': 'cc',
#          'governor': {'@idx': '12', '#text': 'by'},
#          'dependent': {'@idx': '16', '#text': 'or'}},
#         {'@type': 'conj',
#          'governor': {'@idx': '12', '#text': 'by'},
#          'dependent': {'@idx': '17', '#text': 'by'}},
#         {'@type': 'pcomp',
#          'governor': {'@idx': '17', '#text': 'by'},
#          'dependent': {'@idx': '18', '#text': 'dying'}},
#         {'@type': 'prep',
#          'governor': {'@idx': '18', '#text': 'dying'},
#          'dependent': {'@idx': '19', '#text': 'in'}},
#         {'@type': 'det',
#          'governor': {'@idx': '21', '#text': 'dream'},
#          'dependent': {'@idx': '20', '#text': 'the'}},
#         {'@type': 'pobj',
#          'governor': {'@idx': '19', '#text': 'in'},
#          'dependent': {'@idx': '21', '#text': 'dream'}}]},
#       'collapsed-dependencies': {'dep': [{'@type': 'amod',
#          'governor': {'@idx': '2', '#text': 'dream'},
#          'dependent': {'@idx': '1', '#text': 'Tiered'}},
#         {'@type': 'nsubjpass',
#          'governor': {'@idx': '8', '#text': 'used'},
#          'dependent': {'@idx': '2', '#text': 'dream'}},
#         {'@type': 'det',
#          'governor': {'@idx': '6', '#text': 'strategies'},
#          'dependent': {'@idx': '4', '#text': 'a'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '6', '#text': 'strategies'},
#          'dependent': {'@idx': '5', '#text': 'dream'}},
#         {'@type': 'prep_within',
#          'governor': {'@idx': '2', '#text': 'dream'},
#          'dependent': {'@idx': '6', '#text': 'strategies'}},
#         {'@type': 'auxpass',
#          'governor': {'@idx': '8', '#text': 'used'},
#          'dependent': {'@idx': '7', '#text': 'are'}},
#         {'@type': 'nsubj',
#          'governor': {'@idx': '11', '#text': 'awaken'},
#          'dependent': {'@idx': '10', '#text': 'dreamers'}},
#         {'@type': 'conj_and',
#          'governor': {'@idx': '8', '#text': 'used'},
#          'dependent': {'@idx': '11', '#text': 'awaken'}},
#         {'@type': 'det',
#          'governor': {'@idx': '15', '#text': 'kick'},
#          'dependent': {'@idx': '13', '#text': 'a'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '15', '#text': 'kick'},
#          'dependent': {'@idx': '14', '#text': 'sudden'}},
#         {'@type': 'prep_by',
#          'governor': {'@idx': '11', '#text': 'awaken'},
#          'dependent': {'@idx': '15', '#text': 'kick'}},
#         {'@type': 'conj_or',
#          'governor': {'@idx': '15', '#text': 'kick'},
#          'dependent': {'@idx': '18', '#text': 'dying'}},
#         {'@type': 'det',
#          'governor': {'@idx': '21', '#text': 'dream'},
#          'dependent': {'@idx': '20', '#text': 'the'}},
#         {'@type': 'prep_in',
#          'governor': {'@idx': '18', '#text': 'dying'},
#          'dependent': {'@idx': '21', '#text': 'dream'}}]},
#       'collapsed-ccprocessed-dependencies': {'dep': [{'@type': 'amod',
#          'governor': {'@idx': '2', '#text': 'dream'},
#          'dependent': {'@idx': '1', '#text': 'Tiered'}},
#         {'@type': 'nsubjpass',
#          'governor': {'@idx': '8', '#text': 'used'},
#          'dependent': {'@idx': '2', '#text': 'dream'}},
#         {'@type': 'det',
#          'governor': {'@idx': '6', '#text': 'strategies'},
#          'dependent': {'@idx': '4', '#text': 'a'}},
#         {'@type': 'nn',
#          'governor': {'@idx': '6', '#text': 'strategies'},
#          'dependent': {'@idx': '5', '#text': 'dream'}},
#         {'@type': 'prep_within',
#          'governor': {'@idx': '2', '#text': 'dream'},
#          'dependent': {'@idx': '6', '#text': 'strategies'}},
#         {'@type': 'auxpass',
#          'governor': {'@idx': '8', '#text': 'used'},
#          'dependent': {'@idx': '7', '#text': 'are'}},
#         {'@type': 'nsubj',
#          'governor': {'@idx': '11', '#text': 'awaken'},
#          'dependent': {'@idx': '10', '#text': 'dreamers'}},
#         {'@type': 'conj_and',
#          'governor': {'@idx': '8', '#text': 'used'},
#          'dependent': {'@idx': '11', '#text': 'awaken'}},
#         {'@type': 'det',
#          'governor': {'@idx': '15', '#text': 'kick'},
#          'dependent': {'@idx': '13', '#text': 'a'}},
#         {'@type': 'amod',
#          'governor': {'@idx': '15', '#text': 'kick'},
#          'dependent': {'@idx': '14', '#text': 'sudden'}},
#         {'@type': 'prep_by',
#          'governor': {'@idx': '11', '#text': 'awaken'},
#          'dependent': {'@idx': '15', '#text': 'kick'}},
#         {'@type': 'prep_by',
#          'governor': {'@idx': '11', '#text': 'awaken'},
#          'dependent': {'@idx': '18', '#text': 'dying'}},
#         {'@type': 'conj_or',
#          'governor': {'@idx': '15', '#text': 'kick'},
#          'dependent': {'@idx': '18', '#text': 'dying'}},
#         {'@type': 'det',
#          'governor': {'@idx': '21', '#text': 'dream'},
#          'dependent': {'@idx': '20', '#text': 'the'}},
#         {'@type': 'prep_in',
#          'governor': {'@idx': '18', '#text': 'dying'},
#          'dependent': {'@idx': '21', '#text': 'dream'}}]}},
#      {'@id': '3',
#       'tokens': {'token': [{'@id': '1',
#          'word': 'However',
#          'lemma': 'however',
#          'CharacterOffsetBegin': '417',
#          'CharacterOffsetEnd': '424',
#          'POS': 'RB',
#          'NER': 'O'},
#         {'@id': '2',
#          'word': ',',
#          'lemma': ',',
#          'CharacterOffsetBegin': '424',
#          'CharacterOffsetEnd': '425',
#          'POS': ',',
#          'NER': 'O'},
#         {'@id': '3',
#          'word': 'if',
#          'lemma': 'if',
#          'CharacterOffsetBegin': '426',
#          'CharacterOffsetEnd': '428',
#          'POS': 'IN',
#          'NER': 'O'},
#         {'@id': '4',
#          'word': 'the',
#          'lemma': 'the',
#          'CharacterOffsetBegin': '429',
#          'CharacterOffsetEnd': '432',
#          'POS': 'DT',
#          'NER': 'O'},
#         {'@id': '5',
#          'word': 'dreamer',
#          'lemma': 'dreamer',
#          'CharacterOffsetBegin': '433',
#          'CharacterOffsetEnd': '440',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '6',
#          'word': 'is',
#          'lemma': 'be',
#          'CharacterOffsetBegin': '441',
#          'CharacterOffsetEnd': '443',
#          'POS': 'VBZ',
#          'NER': 'O'},
#         {'@id': '7',
#          'word': 'the',
#          'lemma': 'the',
#          'CharacterOffsetBegin': '444',
#          'CharacterOffsetEnd': '447',
#          'POS': 'DT',
#          'NER': 'O'},
#         {'@id': '8',
#          'word': 'one',
#          'lemma': 'one',
#          'CharacterOffsetBegin': '448',
#          'CharacterOffsetEnd': '451',
#          'POS': 'NN',
#          'NER': 'NUMBER',
#          'NormalizedNER': '1.0'},
#         {'@id': '9',
#          'word': 'who',
#          'lemma': 'who',
#          'CharacterOffsetBegin': '452',
#          'CharacterOffsetEnd': '455',
#          'POS': 'WP',
#          'NER': 'O'},
#         {'@id': '10',
#          'word': 'dies',
#          'lemma': 'die',
#          'CharacterOffsetBegin': '456',
#          'CharacterOffsetEnd': '460',
#          'POS': 'VBZ',
#          'NER': 'O'},
#         {'@id': '11',
#          'word': ',',
#          'lemma': ',',
#          'CharacterOffsetBegin': '460',
#          'CharacterOffsetEnd': '461',
#          'POS': ',',
#          'NER': 'O'},
#         {'@id': '12',
#          'word': 'the',
#          'lemma': 'the',
#          'CharacterOffsetBegin': '462',
#          'CharacterOffsetEnd': '465',
#          'POS': 'DT',
#          'NER': 'O'},
#         {'@id': '13',
#          'word': 'dream',
#          'lemma': 'dream',
#          'CharacterOffsetBegin': '466',
#          'CharacterOffsetEnd': '471',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '14',
#          'word': '``',
#          'lemma': '``',
#          'CharacterOffsetBegin': '472',
#          'CharacterOffsetEnd': '473',
#          'POS': '``',
#          'NER': 'O'},
#         {'@id': '15',
#          'word': 'collapses',
#          'lemma': 'collapse',
#          'CharacterOffsetBegin': '473',
#          'CharacterOffsetEnd': '482',
#          'POS': 'VBZ',
#          'NER': 'O'},
#         {'@id': '16',
#          'word': "''",
#          'lemma': "''",
#          'CharacterOffsetBegin': '482',
#          'CharacterOffsetEnd': '483',
#          'POS': "''",
#          'NER': 'O'},
#         {'@id': '17',
#          'word': '.',
#          'lemma': '.',
#          'CharacterOffsetBegin': '483',
#          'CharacterOffsetEnd': '484',
#          'POS': '.',
#          'NER': 'O'}]},
#       'parse': "(ROOT (S (ADVP (RB However)) (, ,) (SBAR (IN if) (S (NP (DT the) (NN dreamer)) (VP (VBZ is) (NP (NP (DT the) (NN one)) (SBAR (WHNP (WP who)) (S (VP (VBZ dies)))))))) (, ,) (NP (DT the) (NN dream)) (VP (`` ``) (VBZ collapses) ('' '')) (. .)))",
#       'basic-dependencies': {'dep': [{'@type': 'advmod',
#          'governor': {'@idx': '15', '#text': 'collapses'},
#          'dependent': {'@idx': '1', '#text': 'However'}},
#         {'@type': 'mark',
#          'governor': {'@idx': '8', '#text': 'one'},
#          'dependent': {'@idx': '3', '#text': 'if'}},
#         {'@type': 'det',
#          'governor': {'@idx': '5', '#text': 'dreamer'},
#          'dependent': {'@idx': '4', '#text': 'the'}},
#         {'@type': 'nsubj',
#          'governor': {'@idx': '8', '#text': 'one'},
#          'dependent': {'@idx': '5', '#text': 'dreamer'}},
#         {'@type': 'cop',
#          'governor': {'@idx': '8', '#text': 'one'},
#          'dependent': {'@idx': '6', '#text': 'is'}},
#         {'@type': 'det',
#          'governor': {'@idx': '8', '#text': 'one'},
#          'dependent': {'@idx': '7', '#text': 'the'}},
#         {'@type': 'advcl',
#          'governor': {'@idx': '15', '#text': 'collapses'},
#          'dependent': {'@idx': '8', '#text': 'one'}},
#         {'@type': 'nsubj',
#          'governor': {'@idx': '10', '#text': 'dies'},
#          'dependent': {'@idx': '9', '#text': 'who'}},
#         {'@type': 'rcmod',
#          'governor': {'@idx': '8', '#text': 'one'},
#          'dependent': {'@idx': '10', '#text': 'dies'}},
#         {'@type': 'det',
#          'governor': {'@idx': '13', '#text': 'dream'},
#          'dependent': {'@idx': '12', '#text': 'the'}},
#         {'@type': 'nsubj',
#          'governor': {'@idx': '15', '#text': 'collapses'},
#          'dependent': {'@idx': '13', '#text': 'dream'}}]},
#       'collapsed-dependencies': {'dep': [{'@type': 'advmod',
#          'governor': {'@idx': '15', '#text': 'collapses'},
#          'dependent': {'@idx': '1', '#text': 'However'}},
#         {'@type': 'mark',
#          'governor': {'@idx': '8', '#text': 'one'},
#          'dependent': {'@idx': '3', '#text': 'if'}},
#         {'@type': 'det',
#          'governor': {'@idx': '5', '#text': 'dreamer'},
#          'dependent': {'@idx': '4', '#text': 'the'}},
#         {'@type': 'nsubj',
#          'governor': {'@idx': '8', '#text': 'one'},
#          'dependent': {'@idx': '5', '#text': 'dreamer'}},
#         {'@type': 'cop',
#          'governor': {'@idx': '8', '#text': 'one'},
#          'dependent': {'@idx': '6', '#text': 'is'}},
#         {'@type': 'det',
#          'governor': {'@idx': '8', '#text': 'one'},
#          'dependent': {'@idx': '7', '#text': 'the'}},
#         {'@type': 'advcl',
#          'governor': {'@idx': '15', '#text': 'collapses'},
#          'dependent': {'@idx': '8', '#text': 'one'}},
#         {'@type': 'nsubj',
#          'governor': {'@idx': '10', '#text': 'dies'},
#          'dependent': {'@idx': '9', '#text': 'who'}},
#         {'@type': 'rcmod',
#          'governor': {'@idx': '8', '#text': 'one'},
#          'dependent': {'@idx': '10', '#text': 'dies'}},
#         {'@type': 'det',
#          'governor': {'@idx': '13', '#text': 'dream'},
#          'dependent': {'@idx': '12', '#text': 'the'}},
#         {'@type': 'nsubj',
#          'governor': {'@idx': '15', '#text': 'collapses'},
#          'dependent': {'@idx': '13', '#text': 'dream'}}]},
#       'collapsed-ccprocessed-dependencies': {'dep': [{'@type': 'advmod',
#          'governor': {'@idx': '15', '#text': 'collapses'},
#          'dependent': {'@idx': '1', '#text': 'However'}},
#         {'@type': 'mark',
#          'governor': {'@idx': '8', '#text': 'one'},
#          'dependent': {'@idx': '3', '#text': 'if'}},
#         {'@type': 'det',
#          'governor': {'@idx': '5', '#text': 'dreamer'},
#          'dependent': {'@idx': '4', '#text': 'the'}},
#         {'@type': 'nsubj',
#          'governor': {'@idx': '8', '#text': 'one'},
#          'dependent': {'@idx': '5', '#text': 'dreamer'}},
#         {'@type': 'cop',
#          'governor': {'@idx': '8', '#text': 'one'},
#          'dependent': {'@idx': '6', '#text': 'is'}},
#         {'@type': 'det',
#          'governor': {'@idx': '8', '#text': 'one'},
#          'dependent': {'@idx': '7', '#text': 'the'}},
#         {'@type': 'advcl',
#          'governor': {'@idx': '15', '#text': 'collapses'},
#          'dependent': {'@idx': '8', '#text': 'one'}},
#         {'@type': 'nsubj',
#          'governor': {'@idx': '10', '#text': 'dies'},
#          'dependent': {'@idx': '9', '#text': 'who'}},
#         {'@type': 'rcmod',
#          'governor': {'@idx': '8', '#text': 'one'},
#          'dependent': {'@idx': '10', '#text': 'dies'}},
#         {'@type': 'det',
#          'governor': {'@idx': '13', '#text': 'dream'},
#          'dependent': {'@idx': '12', '#text': 'the'}},
#         {'@type': 'nsubj',
#          'governor': {'@idx': '15', '#text': 'collapses'},
#          'dependent': {'@idx': '13', '#text': 'dream'}}]}},
#      {'@id': '4',
#       'tokens': {'token': [{'@id': '1',
#          'word': 'Each',
#          'lemma': 'each',
#          'CharacterOffsetBegin': '485',
#          'CharacterOffsetEnd': '489',
#          'POS': 'DT',
#          'NER': 'O'},
#         {'@id': '2',
#          'word': 'extractor',
#          'lemma': 'extractor',
#          'CharacterOffsetBegin': '490',
#          'CharacterOffsetEnd': '499',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '3',
#          'word': 'carries',
#          'lemma': 'carry',
#          'CharacterOffsetBegin': '500',
#          'CharacterOffsetEnd': '507',
#          'POS': 'VBZ',
#          'NER': 'O'},
#         {'@id': '4',
#          'word': 'a',
#          'lemma': 'a',
#          'CharacterOffsetBegin': '508',
#          'CharacterOffsetEnd': '509',
#          'POS': 'DT',
#          'NER': 'O'},
#         {'@id': '5',
#          'word': 'totem',
#          'lemma': 'totem',
#          'CharacterOffsetBegin': '510',
#          'CharacterOffsetEnd': '515',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '6',
#          'word': ',',
#          'lemma': ',',
#          'CharacterOffsetBegin': '515',
#          'CharacterOffsetEnd': '516',
#          'POS': ',',
#          'NER': 'O'},
#         {'@id': '7',
#          'word': 'a',
#          'lemma': 'a',
#          'CharacterOffsetBegin': '517',
#          'CharacterOffsetEnd': '518',
#          'POS': 'DT',
#          'NER': 'O'},
#         {'@id': '8',
#          'word': 'personalized',
#          'lemma': 'personalized',
#          'CharacterOffsetBegin': '519',
#          'CharacterOffsetEnd': '531',
#          'POS': 'JJ',
#          'NER': 'O'},
#         {'@id': '9',
#          'word': 'small',
#          'lemma': 'small',
#          'CharacterOffsetBegin': '532',
#          'CharacterOffsetEnd': '537',
#          'POS': 'JJ',
#          'NER': 'O'},
#         {'@id': '10',
#          'word': 'object',
#          'lemma': 'object',
#          'CharacterOffsetBegin': '538',
#          'CharacterOffsetEnd': '544',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '11',
#          'word': 'whose',
#          'lemma': 'whose',
#          'CharacterOffsetBegin': '545',
#          'CharacterOffsetEnd': '550',
#          'POS': 'WP$',
#          'NER': 'O'},
#         {'@id': '12',
#          'word': 'behavior',
#          'lemma': 'behavior',
#          'CharacterOffsetBegin': '551',
#          'CharacterOffsetEnd': '559',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '13',
#          'word': 'is',
#          'lemma': 'be',
#          'CharacterOffsetBegin': '560',
#          'CharacterOffsetEnd': '562',
#          'POS': 'VBZ',
#          'NER': 'O'},
#         {'@id': '14',
#          'word': 'only',
#          'lemma': 'only',
#          'CharacterOffsetBegin': '563',
#          'CharacterOffsetEnd': '567',
#          'POS': 'RB',
#          'NER': 'O'},
#         {'@id': '15',
#          'word': 'predictable',
#          'lemma': 'predictable',
#          'CharacterOffsetBegin': '568',
#          'CharacterOffsetEnd': '579',
#          'POS': 'JJ',
#          'NER': 'O'},
#         {'@id': '16',
#          'word': 'to',
#          'lemma': 'to',
#          'CharacterOffsetBegin': '580',
#          'CharacterOffsetEnd': '582',
#          'POS': 'TO',
#          'NER': 'O'},
#         {'@id': '17',
#          'word': 'its',
#          'lemma': 'its',
#          'CharacterOffsetBegin': '583',
#          'CharacterOffsetEnd': '586',
#          'POS': 'PRP$',
#          'NER': 'O'},
#         {'@id': '18',
#          'word': 'owner',
#          'lemma': 'owner',
#          'CharacterOffsetBegin': '587',
#          'CharacterOffsetEnd': '592',
#          'POS': 'NN',
#          'NER': 'O'},
#         {'@id': '19',
#          'word': ',',
#          'lemma': ',',
#          'CharacterOffsetBegin': '592',
# ...
#         'end': '43',
#         'head': '42'},
#        {'sentence': '7', 'start': '1', 'end': '2', 'head': '1'},
#        {'sentence': '7', 'start': '17', 'end': '18', 'head': '17'},
#        {'sentence': '8', 'start': '1', 'end': '2', 'head': '1'},
#        {'sentence': '8', 'start': '10', 'end': '11', 'head': '10'},
#        {'sentence': '9', 'start': '5', 'end': '6', 'head': '5'},
#        {'sentence': '11', 'start': '1', 'end': '2', 'head': '1'},
#        {'sentence': '11', 'start': '5', 'end': '6', 'head': '5'},
#        {'sentence': '15', 'start': '12', 'end': '13', 'head': '12'},
#        {'sentence': '26', 'start': '1', 'end': '2', 'head': '1'},
#        {'sentence': '26', 'start': '5', 'end': '6', 'head': '5'},
#        {'sentence': '31', 'start': '10', 'end': '11', 'head': '10'},
#        {'sentence': '35', 'start': '17', 'end': '18', 'head': '17'},
#        {'sentence': '37', 'start': '9', 'end': '10', 'head': '9'},
#        {'sentence': '38', 'start': '1', 'end': '16', 'head': '1'},
#        {'sentence': '38', 'start': '1', 'end': '2', 'head': '1'},
#        {'sentence': '39', 'start': '6', 'end': '7', 'head': '6'},
#        {'sentence': '40', 'start': '1', 'end': '2', 'head': '1'},
#        {'sentence': '41', 'start': '5', 'end': '6', 'head': '5'},
#        {'sentence': '41', 'start': '17', 'end': '18', 'head': '17'},
#        {'sentence': '41', 'start': '22', 'end': '23', 'head': '22'},
#        {'sentence': '42', 'start': '2', 'end': '3', 'head': '2'},
#        {'sentence': '42', 'start': '5', 'end': '6', 'head': '5'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '2',
#         'start': '20',
#         'end': '22',
#         'head': '21'},
#        {'sentence': '3', 'start': '12', 'end': '14', 'head': '13'},
#        {'sentence': '13', 'start': '11', 'end': '13', 'head': '12'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '24',
#         'start': '34',
#         'end': '36',
#         'head': '35'},
#        {'sentence': '21', 'start': '20', 'end': '24', 'head': '20'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '2',
#         'start': '13',
#         'end': '16',
#         'head': '15'},
#        {'sentence': '13', 'start': '17', 'end': '19', 'head': '18'},
#        {'sentence': '19', 'start': '10', 'end': '12', 'head': '11'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '3',
#         'start': '4',
#         'end': '6',
#         'head': '5'},
#        {'sentence': '21', 'start': '34', 'end': '36', 'head': '35'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '21',
#         'start': '28',
#         'end': '40',
#         'head': '28'},
#        {'sentence': '21', 'start': '28', 'end': '29', 'head': '28'},
#        {'sentence': '22', 'start': '24', 'end': '25', 'head': '24'},
#        {'sentence': '38', 'start': '17', 'end': '18', 'head': '17'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '4',
#         'start': '7',
#         'end': '29',
#         'head': '10'},
#        {'sentence': '4', 'start': '4', 'end': '29', 'head': '5'},
#        {'sentence': '4', 'start': '4', 'end': '6', 'head': '5'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '4',
#         'start': '1',
#         'end': '3',
#         'head': '2'},
#        {'sentence': '4', 'start': '17', 'end': '18', 'head': '17'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '4',
#         'start': '17',
#         'end': '29',
#         'head': '18'},
#        {'sentence': '4', 'start': '17', 'end': '19', 'head': '18'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '4',
#         'start': '26',
#         'end': '29',
#         'head': '26'},
#        {'sentence': '4', 'start': '26', 'end': '27', 'head': '26'},
#        {'sentence': '7', 'start': '13', 'end': '14', 'head': '13'},
#        {'sentence': '7', 'start': '43', 'end': '44', 'head': '43'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '5',
#         'start': '5',
#         'end': '15',
#         'head': '7'},
#        {'sentence': '5', 'start': '1', 'end': '4', 'head': '3'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '23',
#         'start': '9',
#         'end': '10',
#         'head': '9'},
#        {'sentence': '33', 'start': '39', 'end': '40', 'head': '39'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '32',
#         'start': '6',
#         'end': '17',
#         'head': '6'},
#        {'sentence': '23', 'start': '13', 'end': '14', 'head': '13'},
#        {'sentence': '24', 'start': '11', 'end': '12', 'head': '11'},
#        {'sentence': '24', 'start': '14', 'end': '15', 'head': '14'},
#        {'sentence': '24', 'start': '34', 'end': '35', 'head': '34'},
#        {'sentence': '26', 'start': '13', 'end': '14', 'head': '13'},
#        {'sentence': '32', 'start': '6', 'end': '7', 'head': '6'},
#        {'sentence': '33', 'start': '10', 'end': '12', 'head': '10'},
#        {'sentence': '33', 'start': '16', 'end': '17', 'head': '16'},
#        {'sentence': '33', 'start': '28', 'end': '29', 'head': '28'},
#        {'sentence': '33', 'start': '67', 'end': '68', 'head': '67'},
#        {'sentence': '33', 'start': '74', 'end': '75', 'head': '74'},
#        {'sentence': '34', 'start': '7', 'end': '8', 'head': '7'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '6',
#         'start': '21',
#         'end': '23',
#         'head': '22'},
#        {'sentence': '11', 'start': '16', 'end': '18', 'head': '17'},
#        {'sentence': '21', 'start': '22', 'end': '24', 'head': '23'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '23',
#         'start': '8',
#         'end': '14',
#         'head': '10'},
#        {'sentence': '33', 'start': '39', 'end': '41', 'head': '40'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '37',
#         'start': '29',
#         'end': '31',
#         'head': '30'},
#        {'sentence': '31', 'start': '29', 'end': '30', 'head': '29'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '8',
#         'start': '24',
#         'end': '27',
#         'head': '26'},
#        {'sentence': '8', 'start': '13', 'end': '15', 'head': '14'},
#        {'sentence': '12', 'start': '4', 'end': '5', 'head': '4'},
#        {'sentence': '12', 'start': '9', 'end': '10', 'head': '9'},
#        {'sentence': '12', 'start': '24', 'end': '26', 'head': '25'},
#        {'sentence': '14', 'start': '15', 'end': '16', 'head': '15'},
#        {'sentence': '15', 'start': '2', 'end': '4', 'head': '2'},
#        {'sentence': '16', 'start': '7', 'end': '9', 'head': '7'},
#        {'sentence': '16', 'start': '16', 'end': '17', 'head': '16'},
#        {'sentence': '16', 'start': '18', 'end': '19', 'head': '18'},
#        {'sentence': '17', 'start': '24', 'end': '28', 'head': '24'},
#        {'sentence': '17', 'start': '24', 'end': '25', 'head': '24'},
#        {'sentence': '17', 'start': '27', 'end': '28', 'head': '27'},
#        {'sentence': '18', 'start': '15', 'end': '16', 'head': '15'},
#        {'sentence': '18', 'start': '36', 'end': '38', 'head': '36'},
#        {'sentence': '26', 'start': '19', 'end': '20', 'head': '19'},
#        {'sentence': '31', 'start': '8', 'end': '9', 'head': '8'},
#        {'sentence': '36', 'start': '3', 'end': '4', 'head': '3'},
#        {'sentence': '36', 'start': '9', 'end': '10', 'head': '9'},
#        {'sentence': '36', 'start': '18', 'end': '19', 'head': '18'},
#        {'sentence': '36', 'start': '32', 'end': '33', 'head': '32'},
#        {'sentence': '36', 'start': '35', 'end': '36', 'head': '35'},
#        {'sentence': '36', 'start': '38', 'end': '41', 'head': '40'},
#        {'sentence': '36', 'start': '38', 'end': '39', 'head': '38'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '37',
#         'start': '32',
#         'end': '39',
#         'head': '33'},
#        {'sentence': '31', 'start': '26', 'end': '28', 'head': '27'},
#        {'sentence': '37', 'start': '32', 'end': '34', 'head': '33'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '7',
#         'start': '33',
#         'end': '35',
#         'head': '34'},
#        {'sentence': '8', 'start': '18', 'end': '20', 'head': '19'},
#        {'sentence': '33', 'start': '25', 'end': '27', 'head': '26'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '8',
#         'start': '21',
#         'end': '23',
#         'head': '22'},
#        {'sentence': '8', 'start': '29', 'end': '30', 'head': '29'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '8',
#         'start': '6',
#         'end': '15',
#         'head': '8'},
#        {'sentence': '36', 'start': '48', 'end': '50', 'head': '49'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '8',
#         'start': '10',
#         'end': '15',
#         'head': '12'},
#        {'sentence': '8', 'start': '21', 'end': '22', 'head': '21'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '8',
#         'start': '29',
#         'end': '32',
#         'head': '30'},
#        {'sentence': '16', 'start': '18', 'end': '21', 'head': '19'},
#        {'sentence': '36', 'start': '32', 'end': '34', 'head': '33'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '9',
#         'start': '23',
#         'end': '25',
#         'head': '24'},
#        {'sentence': '25', 'start': '4', 'end': '6', 'head': '5'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '9',
#         'start': '26',
#         'end': '28',
#         'head': '27'},
#        {'sentence': '11', 'start': '16', 'end': '17', 'head': '16'},
#        {'sentence': '25', 'start': '8', 'end': '10', 'head': '9'},
#        {'sentence': '26', 'start': '22', 'end': '23', 'head': '22'},
#        {'sentence': '41', 'start': '5', 'end': '7', 'head': '6'},
#        {'sentence': '41', 'start': '22', 'end': '24', 'head': '23'},
#        {'sentence': '42', 'start': '5', 'end': '7', 'head': '6'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '33',
#         'start': '33',
#         'end': '34',
#         'head': '33'},
#        {'sentence': '33', 'start': '51', 'end': '52', 'head': '51'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '10',
#         'start': '7',
#         'end': '54',
#         'head': '8'},
#        {'sentence': '11', 'start': '12', 'end': '14', 'head': '13'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '10',
#         'start': '10',
#         'end': '54',
#         'head': '10'},
#        {'sentence': '10', 'start': '10', 'end': '11', 'head': '10'},
#        {'sentence': '10', 'start': '12', 'end': '14', 'head': '13'},
#        {'sentence': '10', 'start': '15', 'end': '17', 'head': '16'},
#        {'sentence': '16', 'start': '1', 'end': '2', 'head': '1'},
#        {'sentence': '18', 'start': '13', 'end': '14', 'head': '13'},
#        {'sentence': '19', 'start': '32', 'end': '34', 'head': '32'},
#        {'sentence': '20', 'start': '27', 'end': '29', 'head': '27'},
#        {'sentence': '31', 'start': '13', 'end': '14', 'head': '13'},
#        {'sentence': '31', 'start': '16', 'end': '17', 'head': '16'},
#        {'sentence': '37', 'start': '27', 'end': '28', 'head': '27'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '10',
#         'start': '18',
#         'end': '54',
#         'head': '18'},
#        {'sentence': '10', 'start': '18', 'end': '19', 'head': '18'},
#        {'sentence': '10', 'start': '20', 'end': '54', 'head': '21'},
#        {'sentence': '14', 'start': '6', 'end': '8', 'head': '6'},
#        {'sentence': '17', 'start': '1', 'end': '2', 'head': '1'},
#        {'sentence': '17', 'start': '28', 'end': '29', 'head': '28'},
#        {'sentence': '19', 'start': '1', 'end': '2', 'head': '1'},
#        {'sentence': '19', 'start': '10', 'end': '11', 'head': '10'},
#        {'sentence': '37', 'start': '54', 'end': '56', 'head': '54'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '10',
#         'start': '36',
#         'end': '51',
#         'head': '36'},
#        {'sentence': '10', 'start': '36', 'end': '37', 'head': '36'},
#        {'sentence': '10', 'start': '38', 'end': '51', 'head': '41'},
#        {'sentence': '31', 'start': '3', 'end': '4', 'head': '3'},
#        {'sentence': '34', 'start': '5', 'end': '6', 'head': '5'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '33',
#         'start': '61',
#         'end': '62',
#         'head': '61'},
#        {'sentence': '40', 'start': '11', 'end': '12', 'head': '11'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '12',
#         'start': '15',
#         'end': '21',
#         'head': '16'},
#        {'sentence': '12', 'start': '15', 'end': '17', 'head': '16'},
#        {'sentence': '40', 'start': '16', 'end': '18', 'head': '17'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '12',
#         'start': '2',
#         'end': '11',
#         'head': '3'},
#        {'sentence': '12', 'start': '29', 'end': '30', 'head': '29'},
#        {'sentence': '12', 'start': '32', 'end': '33', 'head': '32'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '14',
#         'start': '6',
#         'end': '11',
#         'head': '10'},
#        {'sentence': '14', 'start': '2', 'end': '11', 'head': '4'},
#        {'sentence': '14', 'start': '2', 'end': '5', 'head': '4'},
#        {'sentence': '37', 'start': '54', 'end': '57', 'head': '56'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '13',
#         'start': '8',
#         'end': '13',
#         'head': '9'},
#        {'sentence': '14', 'start': '12', 'end': '14', 'head': '13'},
#        {'sentence': '17', 'start': '3', 'end': '5', 'head': '4'},
#        {'sentence': '17', 'start': '21', 'end': '23', 'head': '22'},
#        {'sentence': '21', 'start': '6', 'end': '8', 'head': '7'},
#        {'sentence': '37', 'start': '40', 'end': '43', 'head': '41'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '16',
#         'start': '11',
#         'end': '13',
#         'head': '12'},
#        {'sentence': '16', 'start': '7', 'end': '13', 'head': '9'},
#        {'sentence': '16', 'start': '7', 'end': '10', 'head': '9'},
#        {'sentence': '17', 'start': '33', 'end': '34', 'head': '33'},
#        {'sentence': '18', 'start': '21', 'end': '23', 'head': '21'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '17',
#         'start': '9',
#         'end': '10',
#         'head': '9'},
#        {'sentence': '18', 'start': '18', 'end': '19', 'head': '18'},
#        {'sentence': '18', 'start': '26', 'end': '27', 'head': '26'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '17',
#         'start': '13',
#         'end': '28',
#         'head': '15'},
#        {'sentence': '17', 'start': '13', 'end': '16', 'head': '15'},
#        {'sentence': '17', 'start': '17', 'end': '19', 'head': '18'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '39',
#         'start': '11',
#         'end': '12',
#         'head': '11'},
#        {'sentence': '39', 'start': '16', 'end': '17', 'head': '16'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '39',
#         'start': '11',
#         'end': '13',
#         'head': '12'},
#        {'sentence': '40', 'start': '3', 'end': '5', 'head': '4'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '18',
#         'start': '2',
#         'end': '14',
#         'head': '5'},
#        {'sentence': '18', 'start': '2', 'end': '6', 'head': '5'},
#        {'sentence': '18', 'start': '7', 'end': '14', 'head': '10'},
#        {'sentence': '31', 'start': '16', 'end': '19', 'head': '18'},
#        {'sentence': '36', 'start': '13', 'end': '16', 'head': '15'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '42',
#         'start': '15',
#         'end': '25',
#         'head': '17'},
#        {'sentence': '42', 'start': '15', 'end': '18', 'head': '17'}]},
#      {'mention': [{'@representative': 'true',
#         'sentence': '20',
#         'start': '20',
#         'end': '22',
#         'head': '21'},
#        {'sentence': '37', 'start': '58', 'end': '60', 'head': '59'}]}]}}}}

# %%
characters = {}  # Dictionary to hold character information
for sentence in file['root']['document']['sentences']['sentence']:
    entities = sentence.get('tokens', {}).get('token', [])
    tokens = sentence['tokens']['token']

    # Extract entities and classify them as characters
    for entity in entities:
        if type(entity) is dict and entity.get('NER') is not None and entity[
            'NER'] == 'PERSON':  # Assuming 'type' is the correct key for entity type
            char_name = entity['word']
            if char_name not in characters:
                characters[char_name] = {}
characters
# Out:
# {'Dominick': {},
#  'Cobb': {},
#  'Arthur': {},
#  'Saito': {},
#  'Mallorie': {},
#  'Maurice': {},
#  'Fischer': {},
#  'Robert': {},
#  'Yusuf': {},
#  'Eames': {},
#  'Peter': {},
#  'Browning': {},
#  'Mal': {}}

# %%
# coreference to ida

mentioned_characters = []
mentioned_non_characters = []
character_mention_count = {}

for coreference in file['root']['document']['coreference']['coreference']:
    # find token
    for mention in coreference['mention']:
        # get sentence associated with the mention , -1 because sentence index in mention start from 1
        sentence = file['root']['document']['sentences']['sentence'][int(mention['sentence']) - 1]

        if mention.get('@representative') is not None and mention.get('@representative') == 'true':
            # check if mention is a character
            token = sentence['tokens']['token'][int(mention['head']) - 1]['word']
            if token not in characters:
                break

        if characters[token].get('mentions') is None:
            characters[token]['mentions'] = [mention]
        else:
            characters[token]['mentions'].append(mention)

characters
# Out:
# {'Dominick': {},
#  'Cobb': {'mentions': [{'@representative': 'true',
#     'sentence': '1',
#     'start': '1',
#     'end': '9',
#     'head': '8'},
#    {'sentence': '1', 'start': '8', 'end': '9', 'head': '8'},
#    {'sentence': '5', 'start': '1', 'end': '3', 'head': '1'},
#    {'sentence': '6', 'start': '6', 'end': '23', 'head': '10'},
#    {'sentence': '6', 'start': '6', 'end': '11', 'head': '10'},
#    {'sentence': '6', 'start': '10', 'end': '11', 'head': '10'},
#    {'sentence': '6', 'start': '12', 'end': '14', 'head': '12'},
#    {'sentence': '7', 'start': '6', 'end': '8', 'head': '6'},
#    {'sentence': '9', 'start': '2', 'end': '3', 'head': '2'},
#    {'sentence': '9', 'start': '8', 'end': '9', 'head': '8'},
#    {'sentence': '9', 'start': '16', 'end': '17', 'head': '16'},
#    {'sentence': '9', 'start': '19', 'end': '20', 'head': '19'},
#    {'sentence': '9', 'start': '26', 'end': '27', 'head': '26'},
#    {'sentence': '10', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '10', 'start': '7', 'end': '8', 'head': '7'},
#    {'sentence': '11', 'start': '10', 'end': '11', 'head': '10'},
#    {'sentence': '11', 'start': '12', 'end': '13', 'head': '12'},
#    {'sentence': '12', 'start': '27', 'end': '28', 'head': '27'},
#    {'sentence': '23', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '23', 'start': '6', 'end': '7', 'head': '6'},
#    {'sentence': '24', 'start': '25', 'end': '26', 'head': '25'},
#    {'sentence': '24', 'start': '32', 'end': '33', 'head': '32'},
#    {'sentence': '25', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '25', 'start': '8', 'end': '9', 'head': '8'},
#    {'sentence': '25', 'start': '17', 'end': '18', 'head': '17'},
#    {'sentence': '26', 'start': '9', 'end': '11', 'head': '9'},
#    {'sentence': '31', 'start': '1', 'end': '4', 'head': '1'},
#    {'sentence': '31', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '32', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '32', 'start': '3', 'end': '4', 'head': '3'},
#    {'sentence': '32', 'start': '12', 'end': '13', 'head': '12'},
#    {'sentence': '33', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '33', 'start': '6', 'end': '7', 'head': '6'},
#    {'sentence': '34', 'start': '3', 'end': '6', 'head': '3'},
#    {'sentence': '34', 'start': '3', 'end': '4', 'head': '3'},
#    {'sentence': '35', 'start': '2', 'end': '3', 'head': '2'},
#    {'sentence': '35', 'start': '5', 'end': '6', 'head': '5'},
#    {'sentence': '37', 'start': '7', 'end': '8', 'head': '7'},
#    {'sentence': '39', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '40', 'start': '6', 'end': '7', 'head': '6'},
#    {'sentence': '41', 'start': '8', 'end': '9', 'head': '8'},
#    {'sentence': '41', 'start': '12', 'end': '13', 'head': '12'},
#    {'@representative': 'true',
#     'sentence': '1',
#     'start': '1',
#     'end': '44',
#     'head': '8'},
#    {'sentence': '37', 'start': '7', 'end': '10', 'head': '7'},
#    {'@representative': 'true',
#     'sentence': '1',
#     'start': '1',
#     'end': '9',
#     'head': '8'},
#    {'sentence': '1', 'start': '8', 'end': '9', 'head': '8'},
#    {'sentence': '5', 'start': '1', 'end': '3', 'head': '1'},
#    {'sentence': '6', 'start': '6', 'end': '23', 'head': '10'},
#    {'sentence': '6', 'start': '6', 'end': '11', 'head': '10'},
#    {'sentence': '6', 'start': '10', 'end': '11', 'head': '10'},
#    {'sentence': '6', 'start': '12', 'end': '14', 'head': '12'},
#    {'sentence': '7', 'start': '6', 'end': '8', 'head': '6'},
#    {'sentence': '9', 'start': '2', 'end': '3', 'head': '2'},
#    {'sentence': '9', 'start': '8', 'end': '9', 'head': '8'},
#    {'sentence': '9', 'start': '16', 'end': '17', 'head': '16'},
#    {'sentence': '9', 'start': '19', 'end': '20', 'head': '19'},
#    {'sentence': '9', 'start': '26', 'end': '27', 'head': '26'},
#    {'sentence': '10', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '10', 'start': '7', 'end': '8', 'head': '7'},
#    {'sentence': '11', 'start': '10', 'end': '11', 'head': '10'},
#    {'sentence': '11', 'start': '12', 'end': '13', 'head': '12'},
#    {'sentence': '12', 'start': '27', 'end': '28', 'head': '27'},
#    {'sentence': '23', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '23', 'start': '6', 'end': '7', 'head': '6'},
#    {'sentence': '24', 'start': '25', 'end': '26', 'head': '25'},
#    {'sentence': '24', 'start': '32', 'end': '33', 'head': '32'},
#    {'sentence': '25', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '25', 'start': '8', 'end': '9', 'head': '8'},
#    {'sentence': '25', 'start': '17', 'end': '18', 'head': '17'},
#    {'sentence': '26', 'start': '9', 'end': '11', 'head': '9'},
#    {'sentence': '31', 'start': '1', 'end': '4', 'head': '1'},
#    {'sentence': '31', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '32', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '32', 'start': '3', 'end': '4', 'head': '3'},
#    {'sentence': '32', 'start': '12', 'end': '13', 'head': '12'},
#    {'sentence': '33', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '33', 'start': '6', 'end': '7', 'head': '6'},
#    {'sentence': '34', 'start': '3', 'end': '6', 'head': '3'},
#    {'sentence': '34', 'start': '3', 'end': '4', 'head': '3'},
#    {'sentence': '35', 'start': '2', 'end': '3', 'head': '2'},
#    {'sentence': '35', 'start': '5', 'end': '6', 'head': '5'},
#    {'sentence': '37', 'start': '7', 'end': '8', 'head': '7'},
#    {'sentence': '39', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '40', 'start': '6', 'end': '7', 'head': '6'},
#    {'sentence': '41', 'start': '8', 'end': '9', 'head': '8'},
#    {'sentence': '41', 'start': '12', 'end': '13', 'head': '12'},
#    {'@representative': 'true',
#     'sentence': '1',
#     'start': '1',
#     'end': '44',
#     'head': '8'},
#    {'sentence': '37', 'start': '7', 'end': '10', 'head': '7'}]},
#  'Arthur': {'mentions': [{'@representative': 'true',
#     'sentence': '7',
#     'start': '9',
#     'end': '11',
#     'head': '9'},
#    {'sentence': '1', 'start': '12', 'end': '13', 'head': '12'},
#    {'sentence': '10', 'start': '53', 'end': '54', 'head': '53'},
#    {'sentence': '17', 'start': '13', 'end': '15', 'head': '13'},
#    {'sentence': '19', 'start': '21', 'end': '23', 'head': '21'},
#    {'sentence': '20', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '37', 'start': '35', 'end': '36', 'head': '35'},
#    {'@representative': 'true',
#     'sentence': '7',
#     'start': '9',
#     'end': '11',
#     'head': '9'},
#    {'sentence': '1', 'start': '12', 'end': '13', 'head': '12'},
#    {'sentence': '10', 'start': '53', 'end': '54', 'head': '53'},
#    {'sentence': '17', 'start': '13', 'end': '15', 'head': '13'},
#    {'sentence': '19', 'start': '21', 'end': '23', 'head': '21'},
#    {'sentence': '20', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '37', 'start': '35', 'end': '36', 'head': '35'}]},
#  'Saito': {'mentions': [{'@representative': 'true',
#     'sentence': '1',
#     'start': '39',
#     'end': '43',
#     'head': '42'},
#    {'sentence': '7', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '7', 'start': '17', 'end': '18', 'head': '17'},
#    {'sentence': '8', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '8', 'start': '10', 'end': '11', 'head': '10'},
#    {'sentence': '9', 'start': '5', 'end': '6', 'head': '5'},
#    {'sentence': '11', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '11', 'start': '5', 'end': '6', 'head': '5'},
#    {'sentence': '15', 'start': '12', 'end': '13', 'head': '12'},
#    {'sentence': '26', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '26', 'start': '5', 'end': '6', 'head': '5'},
#    {'sentence': '31', 'start': '10', 'end': '11', 'head': '10'},
#    {'sentence': '35', 'start': '17', 'end': '18', 'head': '17'},
#    {'sentence': '37', 'start': '9', 'end': '10', 'head': '9'},
#    {'sentence': '38', 'start': '1', 'end': '16', 'head': '1'},
#    {'sentence': '38', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '39', 'start': '6', 'end': '7', 'head': '6'},
#    {'sentence': '40', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '41', 'start': '5', 'end': '6', 'head': '5'},
#    {'sentence': '41', 'start': '17', 'end': '18', 'head': '17'},
#    {'sentence': '41', 'start': '22', 'end': '23', 'head': '22'},
#    {'sentence': '42', 'start': '2', 'end': '3', 'head': '2'},
#    {'sentence': '42', 'start': '5', 'end': '6', 'head': '5'},
#    {'@representative': 'true',
#     'sentence': '1',
#     'start': '39',
#     'end': '43',
#     'head': '42'},
#    {'sentence': '7', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '7', 'start': '17', 'end': '18', 'head': '17'},
#    {'sentence': '8', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '8', 'start': '10', 'end': '11', 'head': '10'},
#    {'sentence': '9', 'start': '5', 'end': '6', 'head': '5'},
#    {'sentence': '11', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '11', 'start': '5', 'end': '6', 'head': '5'},
#    {'sentence': '15', 'start': '12', 'end': '13', 'head': '12'},
#    {'sentence': '26', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '26', 'start': '5', 'end': '6', 'head': '5'},
#    {'sentence': '31', 'start': '10', 'end': '11', 'head': '10'},
#    {'sentence': '35', 'start': '17', 'end': '18', 'head': '17'},
#    {'sentence': '37', 'start': '9', 'end': '10', 'head': '9'},
#    {'sentence': '38', 'start': '1', 'end': '16', 'head': '1'},
#    {'sentence': '38', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '39', 'start': '6', 'end': '7', 'head': '6'},
#    {'sentence': '40', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '41', 'start': '5', 'end': '6', 'head': '5'},
#    {'sentence': '41', 'start': '17', 'end': '18', 'head': '17'},
#    {'sentence': '41', 'start': '22', 'end': '23', 'head': '22'},
#    {'sentence': '42', 'start': '2', 'end': '3', 'head': '2'},
#    {'sentence': '42', 'start': '5', 'end': '6', 'head': '5'}]},
#  'Mallorie': {},
#  'Maurice': {},
#  'Fischer': {'mentions': [{'@representative': 'true',
#     'sentence': '8',
#     'start': '24',
#     'end': '27',
#     'head': '26'},
#    {'sentence': '8', 'start': '13', 'end': '15', 'head': '14'},
#    {'sentence': '12', 'start': '4', 'end': '5', 'head': '4'},
#    {'sentence': '12', 'start': '9', 'end': '10', 'head': '9'},
#    {'sentence': '12', 'start': '24', 'end': '26', 'head': '25'},
#    {'sentence': '14', 'start': '15', 'end': '16', 'head': '15'},
#    {'sentence': '15', 'start': '2', 'end': '4', 'head': '2'},
#    {'sentence': '16', 'start': '7', 'end': '9', 'head': '7'},
#    {'sentence': '16', 'start': '16', 'end': '17', 'head': '16'},
#    {'sentence': '16', 'start': '18', 'end': '19', 'head': '18'},
#    {'sentence': '17', 'start': '24', 'end': '28', 'head': '24'},
#    {'sentence': '17', 'start': '24', 'end': '25', 'head': '24'},
#    {'sentence': '17', 'start': '27', 'end': '28', 'head': '27'},
#    {'sentence': '18', 'start': '15', 'end': '16', 'head': '15'},
#    {'sentence': '18', 'start': '36', 'end': '38', 'head': '36'},
#    {'sentence': '26', 'start': '19', 'end': '20', 'head': '19'},
#    {'sentence': '31', 'start': '8', 'end': '9', 'head': '8'},
#    {'sentence': '36', 'start': '3', 'end': '4', 'head': '3'},
#    {'sentence': '36', 'start': '9', 'end': '10', 'head': '9'},
#    {'sentence': '36', 'start': '18', 'end': '19', 'head': '18'},
#    {'sentence': '36', 'start': '32', 'end': '33', 'head': '32'},
#    {'sentence': '36', 'start': '35', 'end': '36', 'head': '35'},
#    {'sentence': '36', 'start': '38', 'end': '41', 'head': '40'},
#    {'sentence': '36', 'start': '38', 'end': '39', 'head': '38'},
#    {'@representative': 'true',
#     'sentence': '8',
#     'start': '24',
#     'end': '27',
#     'head': '26'},
#    {'sentence': '8', 'start': '13', 'end': '15', 'head': '14'},
#    {'sentence': '12', 'start': '4', 'end': '5', 'head': '4'},
#    {'sentence': '12', 'start': '9', 'end': '10', 'head': '9'},
#    {'sentence': '12', 'start': '24', 'end': '26', 'head': '25'},
#    {'sentence': '14', 'start': '15', 'end': '16', 'head': '15'},
#    {'sentence': '15', 'start': '2', 'end': '4', 'head': '2'},
#    {'sentence': '16', 'start': '7', 'end': '9', 'head': '7'},
#    {'sentence': '16', 'start': '16', 'end': '17', 'head': '16'},
#    {'sentence': '16', 'start': '18', 'end': '19', 'head': '18'},
#    {'sentence': '17', 'start': '24', 'end': '28', 'head': '24'},
#    {'sentence': '17', 'start': '24', 'end': '25', 'head': '24'},
#    {'sentence': '17', 'start': '27', 'end': '28', 'head': '27'},
#    {'sentence': '18', 'start': '15', 'end': '16', 'head': '15'},
#    {'sentence': '18', 'start': '36', 'end': '38', 'head': '36'},
#    {'sentence': '26', 'start': '19', 'end': '20', 'head': '19'},
#    {'sentence': '31', 'start': '8', 'end': '9', 'head': '8'},
#    {'sentence': '36', 'start': '3', 'end': '4', 'head': '3'},
#    {'sentence': '36', 'start': '9', 'end': '10', 'head': '9'},
#    {'sentence': '36', 'start': '18', 'end': '19', 'head': '18'},
#    {'sentence': '36', 'start': '32', 'end': '33', 'head': '32'},
#    {'sentence': '36', 'start': '35', 'end': '36', 'head': '35'},
#    {'sentence': '36', 'start': '38', 'end': '41', 'head': '40'},
#    {'sentence': '36', 'start': '38', 'end': '39', 'head': '38'}]},
#  'Robert': {},
#  'Yusuf': {'mentions': [{'@representative': 'true',
#     'sentence': '10',
#     'start': '18',
#     'end': '54',
#     'head': '18'},
#    {'sentence': '10', 'start': '18', 'end': '19', 'head': '18'},
#    {'sentence': '10', 'start': '20', 'end': '54', 'head': '21'},
#    {'sentence': '14', 'start': '6', 'end': '8', 'head': '6'},
#    {'sentence': '17', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '17', 'start': '28', 'end': '29', 'head': '28'},
#    {'sentence': '19', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '19', 'start': '10', 'end': '11', 'head': '10'},
#    {'sentence': '37', 'start': '54', 'end': '56', 'head': '54'},
#    {'@representative': 'true',
#     'sentence': '10',
#     'start': '18',
#     'end': '54',
#     'head': '18'},
#    {'sentence': '10', 'start': '18', 'end': '19', 'head': '18'},
#    {'sentence': '10', 'start': '20', 'end': '54', 'head': '21'},
#    {'sentence': '14', 'start': '6', 'end': '8', 'head': '6'},
#    {'sentence': '17', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '17', 'start': '28', 'end': '29', 'head': '28'},
#    {'sentence': '19', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '19', 'start': '10', 'end': '11', 'head': '10'},
#    {'sentence': '37', 'start': '54', 'end': '56', 'head': '54'}]},
#  'Eames': {'mentions': [{'@representative': 'true',
#     'sentence': '10',
#     'start': '10',
#     'end': '54',
#     'head': '10'},
#    {'sentence': '10', 'start': '10', 'end': '11', 'head': '10'},
#    {'sentence': '10', 'start': '12', 'end': '14', 'head': '13'},
#    {'sentence': '10', 'start': '15', 'end': '17', 'head': '16'},
#    {'sentence': '16', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '18', 'start': '13', 'end': '14', 'head': '13'},
#    {'sentence': '19', 'start': '32', 'end': '34', 'head': '32'},
#    {'sentence': '20', 'start': '27', 'end': '29', 'head': '27'},
#    {'sentence': '31', 'start': '13', 'end': '14', 'head': '13'},
#    {'sentence': '31', 'start': '16', 'end': '17', 'head': '16'},
#    {'sentence': '37', 'start': '27', 'end': '28', 'head': '27'},
#    {'@representative': 'true',
#     'sentence': '10',
#     'start': '10',
#     'end': '54',
#     'head': '10'},
#    {'sentence': '10', 'start': '10', 'end': '11', 'head': '10'},
#    {'sentence': '10', 'start': '12', 'end': '14', 'head': '13'},
#    {'sentence': '10', 'start': '15', 'end': '17', 'head': '16'},
#    {'sentence': '16', 'start': '1', 'end': '2', 'head': '1'},
#    {'sentence': '18', 'start': '13', 'end': '14', 'head': '13'},
#    {'sentence': '19', 'start': '32', 'end': '34', 'head': '32'},
#    {'sentence': '20', 'start': '27', 'end': '29', 'head': '27'},
#    {'sentence': '31', 'start': '13', 'end': '14', 'head': '13'},
#    {'sentence': '31', 'start': '16', 'end': '17', 'head': '16'},
#    {'sentence': '37', 'start': '27', 'end': '28', 'head': '27'}]},
#  'Peter': {},
#  'Browning': {'mentions': [{'@representative': 'true',
#     'sentence': '16',
#     'start': '11',
#     'end': '13',
#     'head': '12'},
#    {'sentence': '16', 'start': '7', 'end': '13', 'head': '9'},
#    {'sentence': '16', 'start': '7', 'end': '10', 'head': '9'},
#    {'sentence': '17', 'start': '33', 'end': '34', 'head': '33'},
#    {'sentence': '18', 'start': '21', 'end': '23', 'head': '21'},
#    {'@representative': 'true',
#     'sentence': '16',
#     'start': '11',
#     'end': '13',
#     'head': '12'},
#    {'sentence': '16', 'start': '7', 'end': '13', 'head': '9'},
#    {'sentence': '16', 'start': '7', 'end': '10', 'head': '9'},
#    {'sentence': '17', 'start': '33', 'end': '34', 'head': '33'},
#    {'sentence': '18', 'start': '21', 'end': '23', 'head': '21'}]},
#  'Mal': {'mentions': [{'@representative': 'true',
#     'sentence': '32',
#     'start': '6',
#     'end': '17',
#     'head': '6'},
#    {'sentence': '23', 'start': '13', 'end': '14', 'head': '13'},
#    {'sentence': '24', 'start': '11', 'end': '12', 'head': '11'},
#    {'sentence': '24', 'start': '14', 'end': '15', 'head': '14'},
#    {'sentence': '24', 'start': '34', 'end': '35', 'head': '34'},
#    {'sentence': '26', 'start': '13', 'end': '14', 'head': '13'},
#    {'sentence': '32', 'start': '6', 'end': '7', 'head': '6'},
#    {'sentence': '33', 'start': '10', 'end': '12', 'head': '10'},
#    {'sentence': '33', 'start': '16', 'end': '17', 'head': '16'},
#    {'sentence': '33', 'start': '28', 'end': '29', 'head': '28'},
#    {'sentence': '33', 'start': '67', 'end': '68', 'head': '67'},
#    {'sentence': '33', 'start': '74', 'end': '75', 'head': '74'},
#    {'sentence': '34', 'start': '7', 'end': '8', 'head': '7'},
#    {'@representative': 'true',
#     'sentence': '32',
#     'start': '6',
#     'end': '17',
#     'head': '6'},
#    {'sentence': '23', 'start': '13', 'end': '14', 'head': '13'},
#    {'sentence': '24', 'start': '11', 'end': '12', 'head': '11'},
#    {'sentence': '24', 'start': '14', 'end': '15', 'head': '14'},
#    {'sentence': '24', 'start': '34', 'end': '35', 'head': '34'},
#    {'sentence': '26', 'start': '13', 'end': '14', 'head': '13'},
#    {'sentence': '32', 'start': '6', 'end': '7', 'head': '6'},
#    {'sentence': '33', 'start': '10', 'end': '12', 'head': '10'},
#    {'sentence': '33', 'start': '16', 'end': '17', 'head': '16'},
#    {'sentence': '33', 'start': '28', 'end': '29', 'head': '28'},
#    {'sentence': '33', 'start': '67', 'end': '68', 'head': '67'},
#    {'sentence': '33', 'start': '74', 'end': '75', 'head': '74'},
#    {'sentence': '34', 'start': '7', 'end': '8', 'head': '7'}]}}

# %%
character_mention_count = {}
for character in characters:
    if characters[character].get('mentions') is None:
        character_mention_count[character] = 1
        continue
    character_mention_count[character] = len(characters[character]['mentions']) + 1
character_mention_count
# Out:
# {'Dominick': 1,
#  'Cobb': 88,
#  'Arthur': 14,
#  'Saito': 46,
#  'Mallorie': 1,
#  'Maurice': 1,
#  'Fischer': 48,
#  'Robert': 1,
#  'Yusuf': 18,
#  'Eames': 22,
#  'Peter': 1,
#  'Browning': 10,
#  'Mal': 26}

# %% [markdown]
# Create [sentence][token] -> character (optional) map

# %%
mention_inverse_map = {}

for mention in characters:
    if characters[mention].get('mentions') is None:
        continue
    for m in characters[mention]['mentions']:
        if mention_inverse_map.get(int(m['sentence'])) is None:
            mention_inverse_map[int(m['sentence'])] = {}
        mention_inverse_map[int(m['sentence'])][int(m['head'])] = mention


def get_mentioned_character(sentence_id, token_id):
    if mention_inverse_map.get(sentence_id) is None:
        return None
    character = mention_inverse_map[sentence_id].get(token_id)
    return character


print(get_mentioned_character(1, 8))
print(get_mentioned_character(1, 9))
mention_inverse_map
# Out:
# Cobb
# None
# {1: {8: 'Cobb', 12: 'Arthur', 42: 'Saito'},
#  5: {1: 'Cobb'},
#  6: {10: 'Cobb', 12: 'Cobb'},
#  7: {6: 'Cobb', 9: 'Arthur', 1: 'Saito', 17: 'Saito'},
#  9: {2: 'Cobb', 8: 'Cobb', 16: 'Cobb', 19: 'Cobb', 26: 'Cobb', 5: 'Saito'},
#  10: {1: 'Cobb',
#   7: 'Cobb',
#   53: 'Arthur',
#   18: 'Yusuf',
#   21: 'Yusuf',
#   10: 'Eames',
#   13: 'Eames',
#   16: 'Eames'},
#  11: {10: 'Cobb', 12: 'Cobb', 1: 'Saito', 5: 'Saito'},
#  12: {27: 'Cobb', 4: 'Fischer', 9: 'Fischer', 25: 'Fischer'},
#  23: {1: 'Cobb', 6: 'Cobb', 13: 'Mal'},
#  24: {25: 'Cobb', 32: 'Cobb', 11: 'Mal', 14: 'Mal', 34: 'Mal'},
#  25: {1: 'Cobb', 8: 'Cobb', 17: 'Cobb'},
#  26: {9: 'Cobb', 1: 'Saito', 5: 'Saito', 19: 'Fischer', 13: 'Mal'},
#  31: {1: 'Cobb', 10: 'Saito', 8: 'Fischer', 13: 'Eames', 16: 'Eames'},
#  32: {1: 'Cobb', 3: 'Cobb', 12: 'Cobb', 6: 'Mal'},
#  33: {1: 'Cobb',
#   6: 'Cobb',
#   10: 'Mal',
#   16: 'Mal',
#   28: 'Mal',
#   67: 'Mal',
#   74: 'Mal'},
#  34: {3: 'Cobb', 7: 'Mal'},
#  35: {2: 'Cobb', 5: 'Cobb', 17: 'Saito'},
#  37: {7: 'Cobb', 35: 'Arthur', 9: 'Saito', 54: 'Yusuf', 27: 'Eames'},
#  39: {1: 'Cobb', 6: 'Saito'},
#  40: {6: 'Cobb', 1: 'Saito'},
#  41: {8: 'Cobb', 12: 'Cobb', 5: 'Saito', 17: 'Saito', 22: 'Saito'},
#  17: {13: 'Arthur',
#   24: 'Fischer',
#   27: 'Fischer',
#   1: 'Yusuf',
#   28: 'Yusuf',
#   33: 'Browning'},
#  19: {21: 'Arthur', 1: 'Yusuf', 10: 'Yusuf', 32: 'Eames'},
#  20: {1: 'Arthur', 27: 'Eames'},
#  8: {1: 'Saito', 10: 'Saito', 26: 'Fischer', 14: 'Fischer'},
#  15: {12: 'Saito', 2: 'Fischer'},
#  38: {1: 'Saito'},
#  42: {2: 'Saito', 5: 'Saito'},
#  14: {15: 'Fischer', 6: 'Yusuf'},
#  16: {7: 'Fischer',
#   16: 'Fischer',
#   18: 'Fischer',
#   1: 'Eames',
#   12: 'Browning',
#   9: 'Browning'},
#  18: {15: 'Fischer', 36: 'Fischer', 13: 'Eames', 21: 'Browning'},
#  36: {3: 'Fischer',
#   9: 'Fischer',
#   18: 'Fischer',
#   32: 'Fischer',
#   35: 'Fischer',
#   40: 'Fischer',
#   38: 'Fischer'}}

# %%
file['root']['document']['sentences']['sentence'][0]['basic-dependencies']['dep'][2]
# Out:
# {'@type': 'nn',
#  'governor': {'@idx': '8', '#text': 'Cobb'},
#  'dependent': {'@idx': '3', '#text': 'architect'}}

# %%
def print_dep(sentence, character, other, is_dependent):
    print(f"{character} {'(dependant)' if is_dependent else '(governor)'} {'->' if is_dependent else '<-'} {other} {'(dependant)' if not is_dependent else '(governor)'}")
    for token in sentence['tokens']['token']:
        print(token['word'], end=' ')
    print("\n")


def add_dep(dependencies, sentence, dep, type, character, other, is_dependent):
    if dependencies.get(character) is None:
        dependencies[character] = {}
    if dependencies[character].get(type) is None:
        dependencies[character][type] = {}
    role = 'dependant' if is_dependent else 'governor'
    if dependencies[character][type].get(role) is None:
        dependencies[character][type][role] = []
    dependencies[character][type][role].append(other)
    # print_dep(sentence, character, other, is_dependent)

# %%
dep_alg = 'collapsed-ccprocessed-dependencies'

# get all types of dependencies
types = set()
for sentence in file['root']['document']['sentences']['sentence']:
    if sentence.get(dep_alg) is None:
        continue
    for dep in sentence[dep_alg]['dep']:
        types.add(dep['@type'])

dependencies = {}

for t in types:
    # print(f"\n----\n{t}\n---\n")
    for sentence in file['root']['document']['sentences']['sentence']:
        if sentence.get(dep_alg) is None:
            continue

        for dep in sentence[dep_alg]['dep']:
            if dep.get('@type') != t:
                continue

            character = get_mentioned_character(int(sentence['@id']), int(dep.get('dependent').get('@idx')))
            if character is not None:
                other = sentence['tokens']['token'][int(dep.get('governor').get('@idx')) - 1]['lemma']
                if other in characters:
                    continue
                add_dep(dependencies, sentence, dep, t, character, other, True)

            character = get_mentioned_character(int(sentence['@id']), int(dep.get('governor').get('@idx')))
            if character is not None:
                other = sentence['tokens']['token'][int(dep.get('dependent').get('@idx')) - 1]['lemma']
                if other in characters:
                    continue
                add_dep(dependencies, sentence, dep, t, character, other, False)
        # print(dep.get('dependent'))

# %%
dependencies
# Out:
# {'Browning': {'prep_of': {'dependant': ['appearance']},
#   'appos': {'dependant': ['godfather']},
#   'poss': {'dependant': ['subconscious']},
#   'agent': {'dependant': ['orchestrate']}},
#  'Mal': {'prep_of': {'dependant': ['projection', 'projection']},
#   'nsubj': {'dependant': ['convinced',
#     'dream',
#     'commit',
#     'leave',
#     'continue']},
#   'poss': {'dependant': ['death', 'suicide', 'mind']},
#   'prep_with': {'dependant': ['year']},
#   'dobj': {'dependant': ['wake', 'shoot']},
#   'rcmod': {'governor': ['try']}},
#  'Cobb': {'appos': {'governor': ['wife']},
#   'nsubj': {'dependant': ['sell',
#     'succeed',
#     'return',
#     'accept',
#     'assemble',
#     'succeed',
#     'reveal',
#     'spend',
#     'do',
#     'flee',
#     'leave',
#     'enter',
#     'confront',
#     'stay',
#     'refuse',
#     'confess',
#     'responsible',
#     'attain',
#     'choose',
#     'find',
#     'pass']},
#   'prep_to': {'dependant': ['due']},
#   'prep_against': {'dependant': ['clear']},
#   'poss': {'dependant': ['totem',
#     'wife',
#     'influence',
#     'child',
#     'team',
#     'team',
#     'child',
#     'father-in-law',
#     'projection',
#     'projection',
#     'confession']},
#   'conj_but': {'governor': ['Ariadne']},
#   'prep_with': {'dependant': ['flight', 'reality']},
#   'amod': {'governor': ['former']},
#   'prep_except': {'dependant': ['member']},
#   'dobj': {'dependant': ['incriminate']},
#   'nn': {'governor': ['dream', 'architect', 'Dom'], 'dependant': ['reality']},
#   'dep': {'governor': ['perform', 'sabotage', 'associate'],
#    'dependant': ['attack']},
#   'possessive': {'governor': ["'s"]},
#   'conj_and': {'governor': ['partner', 'team', 'Ariadne'],
#    'dependant': ['honor']}},
#  'Yusuf': {'appos': {'governor': ['Ariadne']},
#   'det': {'governor': ['a']},
#   'nsubj': {'dependant': ['drive', 'initiate']},
#   'poss': {'dependant': ['dream', 'kidnapping', 'kick', 'dream']},
#   'rcmod': {'governor': ['concoct']},
#   'conj_and': {'governor': ['Ariadne']}},
#  'Fischer': {'nsubjpass': {'dependant': ['tell']},
#   'xcomp': {'dependant': ['wish']},
#   'cop': {'governor': ['be']},
#   'prep_into': {'dependant': ['go']},
#   'aux': {'governor': ['to']},
#   'nsubj': {'dependant': ['die', 'reconsider', 'enter', 'man'],
#    'governor': ['he']},
#   'partmod': {'governor': ['convince']},
#   'poss': {'dependant': ['body',
#     'attack',
#     'godfather',
#     'father',
#     'father',
#     'man'],
#    'governor': ['he']},
#   'prep_with': {'dependant': ['flight']},
#   'amod': {'governor': ['own']},
#   'prep_in': {'dependant': ['plant']},
#   'dobj': {'dependant': ['abduct',
#     'recruit',
#     'convince',
#     'kill',
#     'find',
#     'kick',
#     'bring']},
#   'nn': {'governor': ['heir']},
#   'dep': {'dependant': ['competitor']},
#   'possessive': {'governor': ["'s"]},
#   'conj_and': {'dependant': ['son']}},
#  'Arthur': {'nsubjpass': {'dependant': ['force']},
#   'nsubj': {'dependant': ['perform', 'sell']},
#   'poss': {'dependant': ['dream', 'world']},
#   'nn': {'dependant': ['blast']},
#   'conj_and': {'dependant': ['chemist']}},
#  'Saito': {'prep_for': {'dependant': ['search']},
#   'cop': {'governor': ['be']},
#   'det': {'governor': ['a']},
#   'nsubj': {'governor': ['target'],
#    'dependant': ['reveal',
#     'be',
#     'wish',
#     'use',
#     'accompany',
#     'know',
#     'succumb',
#     'enter',
#     'turn',
#     'play']},
#   'poss': {'dependant': ['competitor', 'wound', 'child', 'child', 'child']},
#   'amod': {'governor': ['powerful', 'japanese', 'aged']},
#   'prep_except': {'dependant': ['member']},
#   'dobj': {'dependant': ['find', 'find']},
#   'nn': {'governor': ['businessman'], 'dependant': ['honor']},
#   'rcmod': {'governor': ['die']},
#   'dep': {'dependant': ['wound']}},
#  'Eames': {'det': {'governor': ['a']},
#   'nsubj': {'dependant': ['take', 'remain', 'detonate']},
#   'poss': {'dependant': ['dream', 'race', 'level']},
#   'nn': {'governor': ['identity']},
#   'agent': {'dependant': ['dream']},
#   'dep': {'dependant': ['team', 'team', 'team']}}}

# %% [markdown]
# Important dependencies:
# - __agent__ - An agent performing the action in a passive sentence, typically following "by," like "Browning (dependant) -> orchestrate (governor)" in "Kidnapping was orchestrated by Browning"
# - __amod__ - Adjectival modifier. An adjective modifying a noun, like "Saito (governor) <- japanese (dependant)" in "Japanese businessman Saito"
# - __dobj__ - Direct object. A noun phrase receiving the action of a transitive verb, like "Fischer (dependant) -> abduct (governor)" in "The team abducts Fischer "
# - __nn__ - Noun compound modifier. A noun modifying another noun, like "Saito (governor) <- businessman (dependant)" in "Japanese businessman Saito"
# - __nsubj__ - Nominal subject. Nominal subject. The main noun or pronoun that the sentence is about, like "Cobb (dependant) -> confront (governor)" in "Cobb confronts his projection"
# - __nsubjpass__ - Passive nominal subject. The subject in a passive sentence, like "Arthur (dependant) -> force (governor)" in "Arthur is forced to improvise"
# - __poss__ - Possession modifier. A possessive noun or pronoun, like "Arthur (dependant) -> dream (governor)" in "They are sedated into Arthur 's dream."
#
# Parsing dependencies to extract:
#  - __actions_taken__ - agent, nsubj
#  - __actions_received__ - dobj, nsubjpass,
#  - __possessions__ - poss
#  - __descriptions__ - amod, nn

# %%
for character in dependencies:
    actions_taken = []
    actions_received = []
    possessions = []
    descriptions = []
    
    for type in dependencies[character]:
        for role in dependencies[character][type]:
            for other in dependencies[character][type][role]:
                if type == 'agent' and role == 'dependant' or type == 'nsubj' and role == 'dependant':
                    actions_taken.append(other)
                if type == 'dobj' and role == 'dependant' or type == 'nsubjpass' and role == 'dependant':
                    actions_received.append(other)
                if type == 'poss' and role == 'dependant':
                    possessions.append(other)
                if type == 'amod' and role == 'governor' or type == 'nn' and role == 'governor':
                    descriptions.append(other)
    dependencies[character] = {
        'actions_taken': actions_taken,
        'actions_received': actions_received,
        'possessions': possessions,
        'descriptions': descriptions
    }
dependencies
# Out:
# {'Browning': {'actions_taken': ['orchestrate'],
#   'actions_received': [],
#   'possessions': ['subconscious'],
#   'descriptions': []},
#  'Mal': {'actions_taken': ['convinced',
#    'dream',
#    'commit',
#    'leave',
#    'continue'],
#   'actions_received': ['wake', 'shoot'],
#   'possessions': ['death', 'suicide', 'mind'],
#   'descriptions': []},
#  'Cobb': {'actions_taken': ['sell',
#    'succeed',
#    'return',
#    'accept',
#    'assemble',
#    'succeed',
#    'reveal',
#    'spend',
#    'do',
#    'flee',
#    'leave',
#    'enter',
#    'confront',
#    'stay',
#    'refuse',
#    'confess',
#    'responsible',
#    'attain',
#    'choose',
#    'find',
#    'pass'],
#   'actions_received': ['incriminate'],
#   'possessions': ['totem',
#    'wife',
#    'influence',
#    'child',
#    'team',
#    'team',
#    'child',
#    'father-in-law',
#    'projection',
#    'projection',
#    'confession'],
#   'descriptions': ['former', 'dream', 'architect', 'Dom']},
#  'Yusuf': {'actions_taken': ['drive', 'initiate'],
#   'actions_received': [],
#   'possessions': ['dream', 'kidnapping', 'kick', 'dream'],
#   'descriptions': []},
#  'Fischer': {'actions_taken': ['die', 'reconsider', 'enter', 'man'],
#   'actions_received': ['tell',
#    'abduct',
#    'recruit',
#    'convince',
#    'kill',
#    'find',
#    'kick',
#    'bring'],
#   'possessions': ['body', 'attack', 'godfather', 'father', 'father', 'man'],
#   'descriptions': ['own', 'heir']},
#  'Arthur': {'actions_taken': ['perform', 'sell'],
#   'actions_received': ['force'],
#   'possessions': ['dream', 'world'],
#   'descriptions': []},
#  'Saito': {'actions_taken': ['reveal',
#    'be',
#    'wish',
#    'use',
#    'accompany',
#    'know',
#    'succumb',
#    'enter',
#    'turn',
#    'play'],
#   'actions_received': ['find', 'find'],
#   'possessions': ['competitor', 'wound', 'child', 'child', 'child'],
#   'descriptions': ['powerful', 'japanese', 'aged', 'businessman']},
#  'Eames': {'actions_taken': ['take', 'remain', 'detonate', 'dream'],
#   'actions_received': [],
#   'possessions': ['dream', 'race', 'level'],
#   'descriptions': ['identity']}}

# %%
#save dependencies to .json file with id of the movie as name
import json

# create directory if doesn't exist
import os
if not os.path.exists('dataset/characters'):
    os.makedirs('dataset/characters')

with open(f'dataset/characters/{movie_id}.json', 'w') as fp:
    json.dump(dependencies, fp)

# %% [markdown]
# __Character Frequency Analysis:__
# Count how often each character's name appears in the summary. More frequent mentions usually indicate a more central role in the narrative.
#
# __Sentiment Analysis:__
# Apply sentiment analysis to the sentences or phrases associated with each character. This can help you understand the narrative's emotional context around each character, indicating their role in the story's tone and themes.
#
# __Network Analysis__
# Create a network graph where nodes represent characters, and edges represent interactions or relationships between them. Analyzing this network can reveal central characters, isolated ones, or key relationships.
#
# Extracting Character Relationships from Plot Summaries by creating a network of interactions-dependencies between characters of any type or of a specific type target of an action, source of an action, etc.
#
# __Role Identification__
# Identify the verbs and actions associated with each character. For instance, a character frequently associated with verbs like 'lead', 'decide', or 'solve' might be a protagonist, while one associated with 'help' or 'support' might be a sidekick.
#
# __Topic Modeling__
# Use topic modeling to identify themes or topics in the movie summary and then see how each character is associated with these topics. This could provide insight into thematic significance.
#
# __Plot Point Association__
# Identify key plot points and see which characters are most involved in these. Characters central to major plot points are often more important to the narrative.
